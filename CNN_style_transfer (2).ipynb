# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
cuda = True if torch.cuda.is_available() else False

N_FFT = 512
N_CHANNELS = round(1 + N_FFT/2)
OUT_CHANNELS = 32


class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()

        # 2-D CNN
        self.conv1 = nn.Conv2d(1, OUT_CHANNELS, kernel_size=(3, 1), stride=1, padding=0)
        self.LeakyReLU = nn.LeakyReLU(0.2)

        # Set the random parameters to be constant
        weight = torch.randn(self.conv1.weight.data.shape)
        self.conv1.weight = torch.nn.Parameter(weight, requires_grad=False)
        bias = torch.zeros(self.conv1.bias.data.shape)
        self.conv1.bias = torch.nn.Parameter(bias, requires_grad=False)

    def forward(self, x_delta):
        out = self.LeakyReLU(self.conv1(x_delta))
        return out


"""
a_random = Variable(torch.randn(1, 1, 257, 430)).float()
model = RandomCNN()
a_O = model(a_random)
print(a_O.shape)
"""
# Out:
# '\na_random = Variable(torch.randn(1, 1, 257, 430)).float()\nmodel = RandomCNN()\na_O = model(a_random)\nprint(a_O.shape)\n'

# %%
import librosa
import numpy as np
import torch
import soundfile
from packaging import version

def librosa_write(outfile, x, sr):
    if version.parse(librosa.__version__) < version.parse('0.8.0'):
        librosa.output.write_wav(outfile, x, sr)
    else:
        soundfile.write(outfile, x, sr)

def wav2spectrum(filename):
    x, sr = librosa.load(filename)
    S = librosa.stft(x, n_fft=N_FFT)
    p = np.angle(S)

    S = np.log1p(np.abs(S))
    return S, sr


def spectrum2wav(spectrum, sr, outfile):
    # Return the all-zero vector with the same shape of `a_content`
    a = np.exp(spectrum) - 1
    p = 2 * np.pi * np.random.random_sample(spectrum.shape) - np.pi
    for i in range(50):
        S = a * np.exp(1j * p)
        x = librosa.istft(S)
        p = np.angle(librosa.stft(x, n_fft=N_FFT))
    librosa_write(outfile, x, sr)


def wav2spectrum_keep_phase(filename):
    x, sr = librosa.load(filename)
    S = librosa.stft(x, n_fft=N_FFT)
    p = np.angle(S)

    S = np.log1p(np.abs(S))
    return S, p, sr


def spectrum2wav_keep_phase(spectrum, p, sr, outfile):
    # Return the all-zero vector with the same shape of `a_content`
    a = np.exp(spectrum) - 1
    for i in range(50):
        S = a * np.exp(1j * p)
        x = librosa.istft(S)
        p = np.angle(librosa.stft(x, n_fft=N_FFT))
    librosa_write(outfile, x, sr)


def compute_content_loss(a_C, a_G):
    """
    Compute the content cost

    Arguments:
    a_C -- tensor of dimension (1, n_C, n_H, n_W)
    a_G -- tensor of dimension (1, n_C, n_H, n_W)

    Returns:
    J_content -- scalar that you compute using equation 1 above
    """
    m, n_C, n_H, n_W = a_G.shape

    # Reshape a_C and a_G to the (m * n_C, n_H * n_W)
    a_C_unrolled = a_C.view(m * n_C, n_H * n_W)
    a_G_unrolled = a_G.view(m * n_C, n_H * n_W)

    # Compute the cost
    J_content = 1.0 / (4 * m * n_C * n_H * n_W) * torch.sum((a_C_unrolled - a_G_unrolled) ** 2)

    return J_content


def gram(A):
    """
    Argument:
    A -- matrix of shape (n_C, n_L)

    Returns:
    GA -- Gram matrix of shape (n_C, n_C)
    """
    GA = torch.matmul(A, A.t())

    return GA


def gram_over_time_axis(A):
    """
    Argument:
    A -- matrix of shape (1, n_C, n_H, n_W)

    Returns:
    GA -- Gram matrix of A along time axis, of shape (n_C, n_C)
    """
    m, n_C, n_H, n_W = A.shape

    # Reshape the matrix to the shape of (n_C, n_L)
    # Reshape a_C and a_G to the (m * n_C, n_H * n_W)
    A_unrolled = A.view(m * n_C * n_H, n_W)
    GA = torch.matmul(A_unrolled, A_unrolled.t())

    return GA


def compute_layer_style_loss(a_S, a_G):
    """
    Arguments:
    a_S -- tensor of dimension (1, n_C, n_H, n_W)
    a_G -- tensor of dimension (1, n_C, n_H, n_W)

    Returns:
    J_style_layer -- tensor representing a scalar style cost.
    """
    m, n_C, n_H, n_W = a_G.shape

    # Reshape the matrix to the shape of (n_C, n_L)
    # Reshape a_C and a_G to the (m * n_C, n_H * n_W)

    GS = gram_over_time_axis(a_S)
    GG = gram_over_time_axis(a_G)

    # Computing the loss
    J_style_layer = 1.0 / (4 * (n_C ** 2) * (n_H * n_W)) * torch.sum((GS - GG) ** 2)

    return J_style_layer


"""
# Test
test_S = torch.randn(1, 6, 2, 2)
test_G = torch.randn(1, 6, 2, 2)
print(test_S)
print(test_G)
print(compute_layer_style_loss(test_S, test_G))


# Test
test_C = torch.randn(1, 6, 2, 2)
test_G = torch.randn(1, 6, 2, 2)
print(test_C)
print(test_G)
print(compute_content_loss(test_C, test_G))
"""
# Out:
# '\n# Test\ntest_S = torch.randn(1, 6, 2, 2)\ntest_G = torch.randn(1, 6, 2, 2)\nprint(test_S)\nprint(test_G)\nprint(compute_layer_style_loss(test_S, test_G))\n\n\n# Test\ntest_C = torch.randn(1, 6, 2, 2)\ntest_G = torch.randn(1, 6, 2, 2)\nprint(test_C)\nprint(test_G)\nprint(compute_content_loss(test_C, test_G))\n'

# %%
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt
from torch.autograd import Variable
import time
import math
import argparse
cuda = True if torch.cuda.is_available() else False

CONTENT_FILENAME = "content.wav"
STYLE_FILENAME = "style.wav"
num_epochs = 20000
learning_rate = 0.002
style_param = 1
content_param = 1e2
print_every = 10
plot_every = 10


a_content, sr = wav2spectrum(CONTENT_FILENAME)
a_style, sr = wav2spectrum(STYLE_FILENAME)

a_content_torch = torch.from_numpy(a_content)[None, None, :, :]
if cuda:
    a_content_torch = a_content_torch.cuda()
print(a_content_torch.shape)
a_style_torch = torch.from_numpy(a_style)[None, None, :, :]
if cuda:
    a_style_torch = a_style_torch.cuda()
print(a_style_torch.shape)

model = RandomCNN()
model.eval()

a_C_var = Variable(a_content_torch, requires_grad=False).float()
a_S_var = Variable(a_style_torch, requires_grad=False).float()
if cuda:
    model = model.cuda()
    a_C_var = a_C_var.cuda()
    a_S_var = a_S_var.cuda()

a_C = model(a_C_var)
a_S = model(a_S_var)


# Optimizer
a_G_var = Variable(torch.randn(a_content_torch.shape) * 1e-3)
if cuda:
    a_G_var = a_G_var.cuda()
a_G_var.requires_grad = True
optimizer = torch.optim.Adam([a_G_var])

# Keep track of losses for plotting
current_loss = 0
all_losses = []

def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)
# Out:
# torch.Size([1, 1, 257, 1082])
# torch.Size([1, 1, 257, 1779])

# %%
start = time.time()
# Train the Model
for epoch in range(1, num_epochs + 1):
    optimizer.zero_grad()
    a_G = model(a_G_var)

    content_loss = content_param * compute_content_loss(a_C, a_G)
    style_loss = style_param * compute_layer_style_loss(a_S, a_G)
    loss = content_loss + style_loss
    loss.backward()
    optimizer.step()

    # print
    if epoch % print_every == 0:
        print("{} {}% {} content_loss:{:4f} style_loss:{:4f} total_loss:{:4f}".format(epoch,
                                                                                      epoch / num_epochs * 100,
                                                                                      timeSince(start),
                                                                                      content_loss.item(),
                                                                                      style_loss.item(), loss.item()))
        current_loss += loss.item()

    # Add current loss avg to list of losses
    if epoch % plot_every == 0:
        all_losses.append(current_loss / plot_every)
        current_loss = 0


gen_spectrum = a_G_var.cpu().data.numpy().squeeze()
gen_audio_C = "output" + ".wav"
spectrum2wav(gen_spectrum, sr, gen_audio_C)

plt.figure()
plt.plot(all_losses)
plt.savefig('loss_curve.png')

plt.figure(figsize=(5, 5))
# we then use the 2nd column.
plt.subplot(1, 1, 1)
plt.title("Content Spectrum")
plt.imsave('Content_Spectrum.png', a_content[:400, :])

plt.figure(figsize=(5, 5))
# we then use the 2nd column.
plt.subplot(1, 1, 1)
plt.title("Style Spectrum")
plt.imsave('Style_Spectrum.png', a_style[:400, :])

plt.figure(figsize=(5, 5))
# we then use the 2nd column.
plt.subplot(1, 1, 1)
plt.title("CNN Voice Transfer Result")
plt.imsave('Gen_Spectrum.png', gen_spectrum[:400, :])
# Out:
# 10 0.05% 0m 0s content_loss:4.741131 style_loss:4348.493164 total_loss:4353.234375
# 20 0.1% 0m 0s content_loss:4.619136 style_loss:4341.846680 total_loss:4346.465820
# 30 0.15% 0m 1s content_loss:4.497856 style_loss:4328.413574 total_loss:4332.911621
# 40 0.2% 0m 2s content_loss:4.383195 style_loss:4306.968262 total_loss:4311.351562
# 50 0.25% 0m 3s content_loss:4.280679 style_loss:4277.099121 total_loss:4281.379883
# 60 0.3% 0m 4s content_loss:4.194449 style_loss:4239.311035 total_loss:4243.505371
# 70 0.35000000000000003% 0m 5s content_loss:4.126801 style_loss:4194.933594 total_loss:4199.060547
# 80 0.4% 0m 5s content_loss:4.077930 style_loss:4145.848145 total_loss:4149.926270
# 90 0.44999999999999996% 0m 6s content_loss:4.045687 style_loss:4094.025635 total_loss:4098.071289
# 100 0.5% 0m 7s content_loss:4.025651 style_loss:4040.937500 total_loss:4044.963135
# 110 0.5499999999999999% 0m 8s content_loss:4.012343 style_loss:3987.163086 total_loss:3991.175537
# 120 0.6% 0m 9s content_loss:4.001451 style_loss:3932.597900 total_loss:3936.599365
# 130 0.65% 0m 10s content_loss:3.991220 style_loss:3877.057861 total_loss:3881.049072
# 140 0.7000000000000001% 0m 11s content_loss:3.981641 style_loss:3820.588135 total_loss:3824.569824
# 150 0.75% 0m 11s content_loss:3.973078 style_loss:3763.384766 total_loss:3767.357910
# 2460 12.3% 3m 34s content_loss:4.564675 style_loss:119.920044 total_loss:124.484718
# 2470 12.35% 3m 34s content_loss:4.564104 style_loss:119.540932 total_loss:124.105034
# 2480 12.4% 3m 35s content_loss:4.563557 style_loss:119.164246 total_loss:123.727806
# 2490 12.45% 3m 36s content_loss:4.563033 style_loss:118.789986 total_loss:123.353020
# 2500 12.5% 3m 37s content_loss:4.562531 style_loss:118.418121 total_loss:122.980652
# 2510 12.55% 3m 38s content_loss:4.562050 style_loss:118.048683 total_loss:122.610733
# 2520 12.6% 3m 39s content_loss:4.561591 style_loss:117.681664 total_loss:122.243256
# 2530 12.65% 3m 40s content_loss:4.561158 style_loss:117.316940 total_loss:121.878098
# 2540 12.7% 3m 41s content_loss:4.560748 style_loss:116.954384 total_loss:121.515129
# 2550 12.75% 3m 41s content_loss:4.560358 style_loss:116.593872 total_loss:121.154228
# 2560 12.8% 3m 42s content_loss:4.559995 style_loss:116.235481 total_loss:120.795479
# 2570 12.85% 3m 43s content_loss:4.559658 style_loss:115.879219 total_loss:120.438873
# 2580 12.9% 3m 44s content_loss:4.559343 style_loss:115.524841 total_loss:120.084183
# 2590 12.950000000000001% 3m 45s content_loss:4.559056 style_loss:115.172287 total_loss:119.731346
# 2600 13.0% 3m 46s content_loss:4.558798 style_loss:114.821571 total_loss:119.380371
# 2610 13.05% 3m 47s content_loss:4.558574 style_loss:114.472694 total_loss:119.031265
# 2620 13.100000000000001% 3m 48s content_loss:4.558383 style_loss:114.125771 total_loss:118.684151
# 2630 13.15% 3m 49s content_loss:4.558223 style_loss:113.780792 total_loss:118.339012
# 2640 13.200000000000001% 3m 49s content_loss:4.558095 style_loss:113.437805 total_loss:117.995903
# 2650 13.25% 3m 50s content_loss:4.557996 style_loss:113.096718 total_loss:117.654716
# 2660 13.3% 3m 51s content_loss:4.557927 style_loss:112.757500 total_loss:117.315430
# 2670 13.350000000000001% 3m 52s content_loss:4.557890 style_loss:112.420235 total_loss:116.978127
# 2680 13.4% 3m 53s content_loss:4.557878 style_loss:112.084984 total_loss:116.642860
# 2690 13.450000000000001% 3m 54s content_loss:4.557900 style_loss:111.751846 total_loss:116.309746
# 2700 13.5% 3m 55s content_loss:4.557952 style_loss:111.420837 total_loss:115.978790
# 2710 13.55% 3m 56s content_loss:4.558037 style_loss:111.091980 total_loss:115.650017
# 2720 13.600000000000001% 3m 56s content_loss:4.558153 style_loss:110.765335 total_loss:115.323486
# 2730 13.65% 3m 57s content_loss:4.558295 style_loss:110.440948 total_loss:114.999245
# 2740 13.700000000000001% 3m 58s content_loss:4.558470 style_loss:110.118881 total_loss:114.677353
# 2750 13.750000000000002% 3m 59s content_loss:4.558676 style_loss:109.799240 total_loss:114.357918
# 2760 13.8% 4m 0s content_loss:4.558911 style_loss:109.482018 total_loss:114.040932
# 2770 13.850000000000001% 4m 1s content_loss:4.559174 style_loss:109.167175 total_loss:113.726349
# 2780 13.900000000000002% 4m 2s content_loss:4.559466 style_loss:108.854713 total_loss:113.414177
# 3440 17.2% 5m 0s content_loss:4.616876 style_loss:93.732079 total_loss:98.348953
# 3450 17.25% 5m 1s content_loss:4.618075 style_loss:93.560570 total_loss:98.178642
# 3460 17.299999999999997% 5m 1s content_loss:4.619282 style_loss:93.389290 total_loss:98.008575
# 3470 17.349999999999998% 5m 2s content_loss:4.620505 style_loss:93.218414 total_loss:97.838921
# 3480 17.4% 5m 3s content_loss:4.621742 style_loss:93.047775 total_loss:97.669518
# 3490 17.45% 5m 4s content_loss:4.623000 style_loss:92.877327 total_loss:97.500328
# 3500 17.5% 5m 5s content_loss:4.624282 style_loss:92.707024 total_loss:97.331306
# 3510 17.549999999999997% 5m 6s content_loss:4.625578 style_loss:92.536713 total_loss:97.162292
# 3520 17.599999999999998% 5m 7s content_loss:4.626890 style_loss:92.366203 total_loss:96.993095
# 3530 17.65% 5m 8s content_loss:4.628215 style_loss:92.195404 total_loss:96.823616
# 3540 17.7% 5m 8s content_loss:4.629559 style_loss:92.024193 total_loss:96.653748
# 3550 17.75% 5m 9s content_loss:4.630923 style_loss:91.852310 total_loss:96.483231
# 3560 17.8% 5m 10s content_loss:4.632315 style_loss:91.679482 total_loss:96.311798
# 3570 17.849999999999998% 5m 11s content_loss:4.633735 style_loss:91.505699 total_loss:96.139435
# 3580 17.9% 5m 12s content_loss:4.635178 style_loss:91.330864 total_loss:95.966042
# 3590 17.95% 5m 13s content_loss:4.636645 style_loss:91.155014 total_loss:95.791656
# 3600 18.0% 5m 14s content_loss:4.638136 style_loss:90.978119 total_loss:95.616257
# 3610 18.05% 5m 15s content_loss:4.639651 style_loss:90.800056 total_loss:95.439705
# 3620 18.099999999999998% 5m 16s content_loss:4.641195 style_loss:90.621025 total_loss:95.262222
# 3630 18.15% 5m 16s content_loss:4.642776 style_loss:90.441002 total_loss:95.083778
# 3640 18.2% 5m 17s content_loss:4.644389 style_loss:90.259781 total_loss:94.904167
# 3650 18.25% 5m 18s content_loss:4.646033 style_loss:90.077431 total_loss:94.723465
# 3660 18.3% 5m 19s content_loss:4.647709 style_loss:89.893890 total_loss:94.541595
# 3670 18.35% 5m 20s content_loss:4.649417 style_loss:89.709068 total_loss:94.358482
# 3680 18.4% 5m 21s content_loss:4.651164 style_loss:89.523003 total_loss:94.174164
# 3690 18.45% 5m 22s content_loss:4.652953 style_loss:89.335579 total_loss:93.988533
# 3700 18.5% 5m 23s content_loss:4.654779 style_loss:89.146667 total_loss:93.801445
# 3710 18.55% 5m 23s content_loss:4.656641 style_loss:88.956261 total_loss:93.612900
# 3720 18.6% 5m 24s content_loss:4.658545 style_loss:88.764381 total_loss:93.422928
# 3730 18.65% 5m 25s content_loss:4.660493 style_loss:88.571045 total_loss:93.231537
# 3740 18.7% 5m 26s content_loss:4.662486 style_loss:88.376022 total_loss:93.038506
# 3750 18.75% 5m 27s content_loss:4.664522 style_loss:88.179169 total_loss:92.843689
# 3760 18.8% 5m 28s content_loss:4.666600 style_loss:87.980385 total_loss:92.646988
# 3770 18.85% 5m 29s content_loss:4.668723 style_loss:87.779549 total_loss:92.448273
# 3780 18.9% 5m 30s content_loss:4.670895 style_loss:87.576729 total_loss:92.247627
# 3790 18.95% 5m 30s content_loss:4.673117 style_loss:87.371681 total_loss:92.044800
# 3800 19.0% 5m 31s content_loss:4.675391 style_loss:87.164352 total_loss:91.839745
# 3810 19.05% 5m 32s content_loss:4.677719 style_loss:86.954712 total_loss:91.632431
# 3820 19.1% 5m 33s content_loss:4.680098 style_loss:86.742691 total_loss:91.422791
# 3830 19.15% 5m 34s content_loss:4.682533 style_loss:86.528183 total_loss:91.210716
# 3840 19.2% 5m 35s content_loss:4.685025 style_loss:86.310974 total_loss:90.996002
# 3850 19.25% 5m 36s content_loss:4.687573 style_loss:86.090942 total_loss:90.778519
# 3860 19.3% 5m 37s content_loss:4.690180 style_loss:85.867752 total_loss:90.557930
# 3870 19.35% 5m 38s content_loss:4.692848 style_loss:85.641144 total_loss:90.333992
# 3880 19.400000000000002% 5m 38s content_loss:4.695577 style_loss:85.411026 total_loss:90.106606
# 3890 19.45% 5m 39s content_loss:4.698363 style_loss:85.177124 total_loss:89.875488
# 3900 19.5% 5m 40s content_loss:4.701213 style_loss:84.939095 total_loss:89.640305
# 3910 19.55% 5m 41s content_loss:4.704129 style_loss:84.696861 total_loss:89.400993
# 3920 19.6% 5m 42s content_loss:4.707112 style_loss:84.450172 total_loss:89.157288
# 3930 19.650000000000002% 5m 43s content_loss:4.710164 style_loss:84.198647 total_loss:88.908813
# 3940 19.7% 5m 44s content_loss:4.713288 style_loss:83.942184 total_loss:88.655472
# 3950 19.75% 5m 45s content_loss:4.716494 style_loss:83.680756 total_loss:88.397247
# 3960 19.8% 5m 45s content_loss:4.719784 style_loss:83.413963 total_loss:88.133743
# 3970 19.85% 5m 46s content_loss:4.723160 style_loss:83.141762 total_loss:87.864922
# 3980 19.900000000000002% 5m 47s content_loss:4.726627 style_loss:82.864357 total_loss:87.590981
# 3990 19.950000000000003% 5m 48s content_loss:4.730190 style_loss:82.581375 total_loss:87.311562
# 4000 20.0% 5m 49s content_loss:4.733854 style_loss:82.292374 total_loss:87.026230
# 4010 20.05% 5m 50s content_loss:4.737616 style_loss:81.996811 total_loss:86.734428
# 4020 20.1% 5m 51s content_loss:4.741477 style_loss:81.694511 total_loss:86.435989
# 4030 20.150000000000002% 5m 52s content_loss:4.745446 style_loss:81.385544 total_loss:86.130989
# 4040 20.200000000000003% 5m 52s content_loss:4.749522 style_loss:81.070053 total_loss:85.819572
# 4050 20.25% 5m 53s content_loss:4.753709 style_loss:80.747780 total_loss:85.501488
# 4060 20.3% 5m 54s content_loss:4.758003 style_loss:80.418594 total_loss:85.176598
# 4070 20.349999999999998% 5m 55s content_loss:4.762409 style_loss:80.082382 total_loss:84.844788
# 4080 20.4% 5m 56s content_loss:4.766924 style_loss:79.738976 total_loss:84.505898
# 4090 20.45% 5m 57s content_loss:4.771545 style_loss:79.388504 total_loss:84.160049
# 4100 20.5% 5m 58s content_loss:4.776282 style_loss:79.031052 total_loss:83.807335
# 4110 20.549999999999997% 5m 59s content_loss:4.781138 style_loss:78.666901 total_loss:83.448036
# 4120 20.599999999999998% 5m 59s content_loss:4.786115 style_loss:78.295982 total_loss:83.082100
# 4130 20.65% 6m 0s content_loss:4.791210 style_loss:77.918495 total_loss:82.709702
# 4140 20.7% 6m 1s content_loss:4.796426 style_loss:77.534241 total_loss:82.330666
# 4150 20.75% 6m 2s content_loss:4.801756 style_loss:77.143761 total_loss:81.945518
# 4160 20.8% 6m 3s content_loss:4.807204 style_loss:76.747444 total_loss:81.554649
# 4170 20.849999999999998% 6m 4s content_loss:4.812763 style_loss:76.345268 total_loss:81.158028
# 4180 20.9% 6m 5s content_loss:4.818435 style_loss:75.937599 total_loss:80.756035
# 4190 20.95% 6m 6s content_loss:4.824217 style_loss:75.524612 total_loss:80.348831
# 4200 21.0% 6m 6s content_loss:4.830103 style_loss:75.106300 total_loss:79.936401
# 4210 21.05% 6m 7s content_loss:4.836094 style_loss:74.683075 total_loss:79.519173
# 4220 21.099999999999998% 6m 8s content_loss:4.842187 style_loss:74.255264 total_loss:79.097450
# 4230 21.15% 6m 9s content_loss:4.848379 style_loss:73.823204 total_loss:78.671585
# 4240 21.2% 6m 10s content_loss:4.854662 style_loss:73.387085 total_loss:78.241745
# 4250 21.25% 6m 11s content_loss:4.861029 style_loss:72.947151 total_loss:77.808182
# 4260 21.3% 6m 12s content_loss:4.867474 style_loss:72.503746 total_loss:77.371223
# 4270 21.349999999999998% 6m 13s content_loss:4.873995 style_loss:72.056946 total_loss:76.930939
# 4280 21.4% 6m 14s content_loss:4.880581 style_loss:71.606758 total_loss:76.487335
# 4290 21.45% 6m 14s content_loss:4.887239 style_loss:71.153328 total_loss:76.040565
# 4300 21.5% 6m 15s content_loss:4.893964 style_loss:70.696678 total_loss:75.590645
# 4310 21.55% 6m 16s content_loss:4.900752 style_loss:70.237076 total_loss:75.137825
# 4320 21.6% 6m 17s content_loss:4.907595 style_loss:69.774841 total_loss:74.682434
# 4330 21.65% 6m 18s content_loss:4.914488 style_loss:69.310287 total_loss:74.224777
# 4340 21.7% 6m 19s content_loss:4.921419 style_loss:68.843437 total_loss:73.764854
# 4350 21.75% 6m 20s content_loss:4.928395 style_loss:68.374481 total_loss:73.302879
# 4360 21.8% 6m 21s content_loss:4.935409 style_loss:67.903595 total_loss:72.839005
# 4370 21.85% 6m 21s content_loss:4.942451 style_loss:67.431076 total_loss:72.373528
# 4380 21.9% 6m 22s content_loss:4.949522 style_loss:66.956909 total_loss:71.906433
# 4390 21.95% 6m 23s content_loss:4.956616 style_loss:66.481186 total_loss:71.437805
# 4400 22.0% 6m 24s content_loss:4.963734 style_loss:66.004364 total_loss:70.968094
# 4410 22.05% 6m 25s content_loss:4.970858 style_loss:65.526596 total_loss:70.497452
# 4420 22.1% 6m 26s content_loss:4.978000 style_loss:65.047951 total_loss:70.025948
# 4430 22.15% 6m 27s content_loss:4.985161 style_loss:64.568535 total_loss:69.553696
# 4770 23.849999999999998% 6m 57s content_loss:5.219038 style_loss:48.064713 total_loss:53.283752
# 4780 23.9% 6m 58s content_loss:5.225420 style_loss:47.573544 total_loss:52.798965
# 4790 23.95% 6m 58s content_loss:5.231776 style_loss:47.082825 total_loss:52.314602
# 4800 24.0% 6m 59s content_loss:5.238102 style_loss:46.592743 total_loss:51.830845
# 4810 24.05% 7m 0s content_loss:5.244397 style_loss:46.103191 total_loss:51.347588
# 4820 24.099999999999998% 7m 1s content_loss:5.250660 style_loss:45.614368 total_loss:50.865028
# 4830 24.15% 7m 2s content_loss:5.256903 style_loss:45.126404 total_loss:50.383308
# 4840 24.2% 7m 3s content_loss:5.263119 style_loss:44.639469 total_loss:49.902588
# 4850 24.25% 7m 4s content_loss:5.269309 style_loss:44.153629 total_loss:49.422939
# 4860 24.3% 7m 5s content_loss:5.275477 style_loss:43.669140 total_loss:48.944618
# 4870 24.349999999999998% 7m 5s content_loss:5.281623 style_loss:43.186104 total_loss:48.467728
# 4880 24.4% 7m 6s content_loss:5.287748 style_loss:42.704472 total_loss:47.992218
# 4890 24.45% 7m 7s content_loss:5.293844 style_loss:42.224361 total_loss:47.518204
# 4900 24.5% 7m 8s content_loss:5.299912 style_loss:41.746151 total_loss:47.046062
# 4910 24.55% 7m 9s content_loss:5.305948 style_loss:41.269623 total_loss:46.575569
# 4920 24.6% 7m 10s content_loss:5.311956 style_loss:40.794968 total_loss:46.106926
# 4930 24.65% 7m 11s content_loss:5.317932 style_loss:40.322098 total_loss:45.640030
# 4940 24.7% 7m 12s content_loss:5.323873 style_loss:39.851009 total_loss:45.174881
# 4950 24.75% 7m 12s content_loss:5.329787 style_loss:39.381538 total_loss:44.711327
# 4960 24.8% 7m 13s content_loss:5.335677 style_loss:38.913830 total_loss:44.249508
# 4970 24.85% 7m 14s content_loss:5.341538 style_loss:38.448242 total_loss:43.789780
# 4980 24.9% 7m 15s content_loss:5.347377 style_loss:37.984665 total_loss:43.332043
# 4990 24.95% 7m 16s content_loss:5.353187 style_loss:37.523251 total_loss:42.876438
# 5000 25.0% 7m 17s content_loss:5.358966 style_loss:37.063950 total_loss:42.422916
# 5010 25.05% 7m 18s content_loss:5.364718 style_loss:36.606895 total_loss:41.971615
# 5020 25.1% 7m 19s content_loss:5.370439 style_loss:36.152302 total_loss:41.522739
# 5030 25.15% 7m 19s content_loss:5.376137 style_loss:35.700287 total_loss:41.076424
# 5040 25.2% 7m 20s content_loss:5.381803 style_loss:35.250626 total_loss:40.632427
# 5050 25.25% 7m 21s content_loss:5.387442 style_loss:34.803341 total_loss:40.190781
# 5060 25.3% 7m 22s content_loss:5.393051 style_loss:34.358654 total_loss:39.751705
# 5070 25.35% 7m 23s content_loss:5.398634 style_loss:33.916481 total_loss:39.315117
# 5080 25.4% 7m 24s content_loss:5.404191 style_loss:33.476879 total_loss:38.881069
# 5090 25.45% 7m 25s content_loss:5.409719 style_loss:33.040028 total_loss:38.449745
# 5430 27.150000000000002% 7m 55s content_loss:5.579611 style_loss:20.270929 total_loss:25.850540
# 5440 27.200000000000003% 7m 56s content_loss:5.583962 style_loss:19.965694 total_loss:25.549656
# 5450 27.250000000000004% 7m 56s content_loss:5.588273 style_loss:19.664795 total_loss:25.253067
# 5460 27.3% 7m 57s content_loss:5.592540 style_loss:19.368143 total_loss:24.960682
# 5470 27.35% 7m 58s content_loss:5.596761 style_loss:19.075659 total_loss:24.672421
# 5480 27.400000000000002% 7m 59s content_loss:5.600942 style_loss:18.787441 total_loss:24.388384
# 5490 27.450000000000003% 8m 0s content_loss:5.605077 style_loss:18.503582 total_loss:24.108658
# 5500 27.500000000000004% 8m 1s content_loss:5.609173 style_loss:18.223833 total_loss:23.833006
# 5510 27.55% 8m 2s content_loss:5.613225 style_loss:17.948103 total_loss:23.561327
# 5520 27.6% 8m 3s content_loss:5.617230 style_loss:17.676395 total_loss:23.293625
# 5530 27.650000000000002% 8m 3s content_loss:5.621192 style_loss:17.408682 total_loss:23.029875
# ...
# 18130 90.64999999999999% 26m 33s content_loss:2.747622 style_loss:0.086182 total_loss:2.833803
# 18140 90.7% 26m 34s content_loss:2.747519 style_loss:0.086166 total_loss:2.833685
# 18150 90.75% 26m 35s content_loss:2.747401 style_loss:0.086141 total_loss:2.833541
# 18160 90.8% 26m 36s content_loss:2.747290 style_loss:0.086117 total_loss:2.833408
# 18170 90.85% 26m 37s content_loss:2.747203 style_loss:0.086099 total_loss:2.833302
# 18180 90.9% 26m 38s content_loss:2.747094 style_loss:0.086085 total_loss:2.833179
# 18190 90.95% 26m 39s content_loss:2.746962 style_loss:0.086065 total_loss:2.833028
# 18200 91.0% 26m 40s content_loss:2.746863 style_loss:0.086045 total_loss:2.832908
# 18210 91.05% 26m 41s content_loss:2.746802 style_loss:0.086037 total_loss:2.832839
# 18220 91.10000000000001% 26m 41s content_loss:2.746682 style_loss:0.086007 total_loss:2.832689
# 18230 91.14999999999999% 26m 42s content_loss:2.746524 style_loss:0.086011 total_loss:2.832536
# 18240 91.2% 26m 43s content_loss:2.746382 style_loss:0.086053 total_loss:2.832435
# 18250 91.25% 26m 44s content_loss:2.746238 style_loss:0.086134 total_loss:2.832372
# 18260 91.3% 26m 45s content_loss:2.746205 style_loss:0.085985 total_loss:2.832190
# 18270 91.35% 26m 46s content_loss:2.746145 style_loss:0.085919 total_loss:2.832064
# 18280 91.4% 26m 47s content_loss:2.746080 style_loss:0.085896 total_loss:2.831975
# 18290 91.45% 26m 48s content_loss:2.746032 style_loss:0.085902 total_loss:2.831933
# 18300 91.5% 26m 48s content_loss:2.745844 style_loss:0.085886 total_loss:2.831730
# 18310 91.55% 26m 49s content_loss:2.745697 style_loss:0.085942 total_loss:2.831639
# 18320 91.60000000000001% 26m 50s content_loss:2.745586 style_loss:0.085963 total_loss:2.831548
# 18330 91.64999999999999% 26m 51s content_loss:2.745516 style_loss:0.085897 total_loss:2.831412
# 18340 91.7% 26m 52s content_loss:2.745431 style_loss:0.085866 total_loss:2.831296
# 18350 91.75% 26m 53s content_loss:2.745301 style_loss:0.085921 total_loss:2.831222
# 18360 91.8% 26m 54s content_loss:2.745195 style_loss:0.085926 total_loss:2.831122
# 18370 91.85% 26m 55s content_loss:2.745160 style_loss:0.085806 total_loss:2.830966
# 18380 91.9% 26m 56s content_loss:2.745078 style_loss:0.085777 total_loss:2.830855
# 18390 91.95% 26m 56s content_loss:2.744995 style_loss:0.085756 total_loss:2.830751
# 18400 92.0% 26m 57s content_loss:2.744982 style_loss:0.085734 total_loss:2.830716
# 18410 92.05% 26m 58s content_loss:2.744905 style_loss:0.085730 total_loss:2.830635
# 18420 92.10000000000001% 26m 59s content_loss:2.744640 style_loss:0.085882 total_loss:2.830521
# 18430 92.15% 27m 0s content_loss:2.744678 style_loss:0.085686 total_loss:2.830363
# 18440 92.2% 27m 1s content_loss:2.744551 style_loss:0.085695 total_loss:2.830247
# 18450 92.25% 27m 2s content_loss:2.744434 style_loss:0.085715 total_loss:2.830149
# 18460 92.30000000000001% 27m 3s content_loss:2.744344 style_loss:0.085710 total_loss:2.830054
# 18470 92.35% 27m 3s content_loss:2.744254 style_loss:0.085704 total_loss:2.829958
# 18480 92.4% 27m 4s content_loss:2.744145 style_loss:0.085733 total_loss:2.829879
# 18490 92.45% 27m 5s content_loss:2.744067 style_loss:0.085708 total_loss:2.829775
# 18500 92.5% 27m 6s content_loss:2.744005 style_loss:0.085644 total_loss:2.829649
# 18510 92.55% 27m 7s content_loss:2.743911 style_loss:0.085647 total_loss:2.829558
# 18520 92.60000000000001% 27m 8s content_loss:2.743790 style_loss:0.085709 total_loss:2.829500
# 18530 92.65% 27m 9s content_loss:2.743738 style_loss:0.085625 total_loss:2.829364
# 18540 92.7% 27m 10s content_loss:2.743693 style_loss:0.085561 total_loss:2.829254
# 18550 92.75% 27m 10s content_loss:2.743601 style_loss:0.085568 total_loss:2.829169
# 18560 92.80000000000001% 27m 11s content_loss:2.743440 style_loss:0.085735 total_loss:2.829175
# 18570 92.85% 27m 12s content_loss:2.743421 style_loss:0.085586 total_loss:2.829007
# 18580 92.9% 27m 13s content_loss:2.743455 style_loss:0.085484 total_loss:2.828939
# 18590 92.95% 27m 14s content_loss:2.743358 style_loss:0.085478 total_loss:2.828836
# 18600 93.0% 27m 15s content_loss:2.743257 style_loss:0.085483 total_loss:2.828741
# 18610 93.05% 27m 16s content_loss:2.743187 style_loss:0.085472 total_loss:2.828659
# 18620 93.10000000000001% 27m 17s content_loss:2.743161 style_loss:0.085451 total_loss:2.828613
# 18630 93.15% 27m 18s content_loss:2.743175 style_loss:0.085481 total_loss:2.828656
# 18640 93.2% 27m 18s content_loss:2.742938 style_loss:0.085509 total_loss:2.828447
# 18650 93.25% 27m 19s content_loss:2.742872 style_loss:0.085499 total_loss:2.828370
# 18660 93.30000000000001% 27m 20s content_loss:2.742874 style_loss:0.085406 total_loss:2.828281
# 18670 93.35% 27m 21s content_loss:2.742840 style_loss:0.085386 total_loss:2.828226
# 18680 93.4% 27m 22s content_loss:2.742779 style_loss:0.085382 total_loss:2.828161
# 18690 93.45% 27m 23s content_loss:2.742712 style_loss:0.085368 total_loss:2.828080
# 18700 93.5% 27m 24s content_loss:2.742650 style_loss:0.085364 total_loss:2.828015
# 18710 93.55% 27m 25s content_loss:2.742607 style_loss:0.085353 total_loss:2.827960
# 18720 93.60000000000001% 27m 25s content_loss:2.742532 style_loss:0.085349 total_loss:2.827881
# 18730 93.65% 27m 26s content_loss:2.742464 style_loss:0.085339 total_loss:2.827803
# 18740 93.7% 27m 27s content_loss:2.742426 style_loss:0.085326 total_loss:2.827752
# 18750 93.75% 27m 28s content_loss:2.742381 style_loss:0.085320 total_loss:2.827701
# 18760 93.8% 27m 29s content_loss:2.742291 style_loss:0.085314 total_loss:2.827605
# 18770 93.85% 27m 30s content_loss:2.742233 style_loss:0.085309 total_loss:2.827542
# 18780 93.89999999999999% 27m 31s content_loss:2.742228 style_loss:0.085296 total_loss:2.827524
# 18790 93.95% 27m 32s content_loss:2.742164 style_loss:0.085287 total_loss:2.827451
# 18800 94.0% 27m 33s content_loss:2.742050 style_loss:0.085299 total_loss:2.827349
# 18810 94.05% 27m 33s content_loss:2.741987 style_loss:0.085300 total_loss:2.827287
# 18820 94.1% 27m 34s content_loss:2.741903 style_loss:0.085342 total_loss:2.827244
# 18830 94.15% 27m 35s content_loss:2.741737 style_loss:0.085617 total_loss:2.827353
# 18840 94.19999999999999% 27m 36s content_loss:2.741879 style_loss:0.085248 total_loss:2.827127
# 18850 94.25% 27m 37s content_loss:2.741855 style_loss:0.085231 total_loss:2.827086
# 18860 94.3% 27m 38s content_loss:2.741719 style_loss:0.085299 total_loss:2.827018
# 18870 94.35% 27m 39s content_loss:2.741665 style_loss:0.085308 total_loss:2.826973
# 18880 94.39999999999999% 27m 40s content_loss:2.741622 style_loss:0.085295 total_loss:2.826917
# 18890 94.45% 27m 40s content_loss:2.741558 style_loss:0.085322 total_loss:2.826880
# 18900 94.5% 27m 41s content_loss:2.741492 style_loss:0.085365 total_loss:2.826857
# 18910 94.55% 27m 42s content_loss:2.741481 style_loss:0.085292 total_loss:2.826773
# 18920 94.6% 27m 43s content_loss:2.741454 style_loss:0.085261 total_loss:2.826715
# 18930 94.65% 27m 44s content_loss:2.741371 style_loss:0.085328 total_loss:2.826699
# 18940 94.69999999999999% 27m 45s content_loss:2.741297 style_loss:0.085388 total_loss:2.826685
# 18950 94.75% 27m 46s content_loss:2.741344 style_loss:0.085223 total_loss:2.826567
# 18960 94.8% 27m 47s content_loss:2.741347 style_loss:0.085180 total_loss:2.826526
# 18970 94.85% 27m 47s content_loss:2.741369 style_loss:0.085170 total_loss:2.826539
# 18980 94.89999999999999% 27m 48s content_loss:2.741313 style_loss:0.085161 total_loss:2.826475
# 18990 94.95% 27m 49s content_loss:2.741200 style_loss:0.085188 total_loss:2.826388
# 19000 95.0% 27m 50s content_loss:2.741120 style_loss:0.085245 total_loss:2.826365
# 19010 95.05% 27m 51s content_loss:2.741019 style_loss:0.085360 total_loss:2.826379
# 19020 95.1% 27m 52s content_loss:2.741052 style_loss:0.085206 total_loss:2.826258
# 19030 95.15% 27m 53s content_loss:2.741064 style_loss:0.085137 total_loss:2.826201
# 19040 95.19999999999999% 27m 54s content_loss:2.741074 style_loss:0.085108 total_loss:2.826182
# 19050 95.25% 27m 55s content_loss:2.741078 style_loss:0.085112 total_loss:2.826190
# 19060 95.3% 27m 55s content_loss:2.740934 style_loss:0.085111 total_loss:2.826044
# 19070 95.35% 27m 56s content_loss:2.740834 style_loss:0.085178 total_loss:2.826012
# 19080 95.39999999999999% 27m 57s content_loss:2.740758 style_loss:0.085230 total_loss:2.825988
# 19090 95.45% 27m 58s content_loss:2.740762 style_loss:0.085135 total_loss:2.825897
# 19100 95.5% 27m 59s content_loss:2.740741 style_loss:0.085098 total_loss:2.825838
# 19110 95.55% 28m 0s content_loss:2.740648 style_loss:0.085180 total_loss:2.825827
# 19120 95.6% 28m 1s content_loss:2.740591 style_loss:0.085213 total_loss:2.825804
# 19130 95.65% 28m 2s content_loss:2.740647 style_loss:0.085043 total_loss:2.825690
# 19140 95.7% 28m 2s content_loss:2.740645 style_loss:0.085007 total_loss:2.825652
# 19150 95.75% 28m 3s content_loss:2.740676 style_loss:0.084992 total_loss:2.825668
# 19160 95.8% 28m 4s content_loss:2.740605 style_loss:0.084985 total_loss:2.825590
# 19170 95.85000000000001% 28m 5s content_loss:2.740496 style_loss:0.085016 total_loss:2.825512
# 19180 95.89999999999999% 28m 6s content_loss:2.740408 style_loss:0.085093 total_loss:2.825501
# 19190 95.95% 28m 7s content_loss:2.740350 style_loss:0.085133 total_loss:2.825483
# 19200 96.0% 28m 8s content_loss:2.740384 style_loss:0.085005 total_loss:2.825388
# 19210 96.05% 28m 9s content_loss:2.740357 style_loss:0.084983 total_loss:2.825340
# 19220 96.1% 28m 10s content_loss:2.740269 style_loss:0.085061 total_loss:2.825329
# 19230 96.15% 28m 10s content_loss:2.740167 style_loss:0.085213 total_loss:2.825380
# 19240 96.2% 28m 11s content_loss:2.740290 style_loss:0.084935 total_loss:2.825225
# 19250 96.25% 28m 12s content_loss:2.740314 style_loss:0.084911 total_loss:2.825225
# 19260 96.3% 28m 13s content_loss:2.740246 style_loss:0.084914 total_loss:2.825160
# 19270 96.35000000000001% 28m 14s content_loss:2.740207 style_loss:0.084914 total_loss:2.825121
# 19280 96.39999999999999% 28m 15s content_loss:2.740220 style_loss:0.084896 total_loss:2.825116
# 19290 96.45% 28m 16s content_loss:2.740232 style_loss:0.084898 total_loss:2.825130
# 19300 96.5% 28m 17s content_loss:2.740109 style_loss:0.084903 total_loss:2.825012
# 19310 96.55% 28m 17s content_loss:2.740029 style_loss:0.084963 total_loss:2.824992
# 19320 96.6% 28m 18s content_loss:2.739947 style_loss:0.085062 total_loss:2.825009
# 19330 96.65% 28m 19s content_loss:2.739971 style_loss:0.084961 total_loss:2.824932
# 19340 96.7% 28m 20s content_loss:2.739982 style_loss:0.084899 total_loss:2.824882
