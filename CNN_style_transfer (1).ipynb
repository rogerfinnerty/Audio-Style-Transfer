# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
cuda = True if torch.cuda.is_available() else False

N_FFT = 512
N_CHANNELS = round(1 + N_FFT/2)
OUT_CHANNELS = 32


class RandomCNN(nn.Module):
    def __init__(self):
        super(RandomCNN, self).__init__()

        # 2-D CNN
        self.conv1 = nn.Conv2d(1, OUT_CHANNELS, kernel_size=(3, 1), stride=1, padding=0)
        self.LeakyReLU = nn.LeakyReLU(0.2)

        # Set the random parameters to be constant.
        weight = torch.randn(self.conv1.weight.data.shape)
        self.conv1.weight = torch.nn.Parameter(weight, requires_grad=False)
        bias = torch.zeros(self.conv1.bias.data.shape)
        self.conv1.bias = torch.nn.Parameter(bias, requires_grad=False)

    def forward(self, x_delta):
        out = self.LeakyReLU(self.conv1(x_delta))
        return out


"""
a_random = Variable(torch.randn(1, 1, 257, 430)).float()
model = RandomCNN()
a_O = model(a_random)
print(a_O.shape)
"""
# Out:
# '\na_random = Variable(torch.randn(1, 1, 257, 430)).float()\nmodel = RandomCNN()\na_O = model(a_random)\nprint(a_O.shape)\n'

# %%
import librosa
import numpy as np
import torch
import soundfile
from packaging import version

def librosa_write(outfile, x, sr):
    if version.parse(librosa.__version__) < version.parse('0.8.0'):
        librosa.output.write_wav(outfile, x, sr)
    else:
        soundfile.write(outfile, x, sr)

def wav2spectrum(filename):
    x, sr = librosa.load(filename)
    S = librosa.stft(x, n_fft=N_FFT)
    p = np.angle(S)

    S = np.log1p(np.abs(S))
    return S, sr


def spectrum2wav(spectrum, sr, outfile):
    # Return the all-zero vector with the same shape of `a_content`
    a = np.exp(spectrum) - 1
    p = 2 * np.pi * np.random.random_sample(spectrum.shape) - np.pi
    for i in range(50):
        S = a * np.exp(1j * p)
        x = librosa.istft(S)
        p = np.angle(librosa.stft(x, n_fft=N_FFT))
    librosa_write(outfile, x, sr)


def wav2spectrum_keep_phase(filename):
    x, sr = librosa.load(filename)
    S = librosa.stft(x, n_fft=N_FFT)
    p = np.angle(S)

    S = np.log1p(np.abs(S))
    return S, p, sr


def spectrum2wav_keep_phase(spectrum, p, sr, outfile):
    # Return the all-zero vector with the same shape of `a_content`
    a = np.exp(spectrum) - 1
    for i in range(50):
        S = a * np.exp(1j * p)
        x = librosa.istft(S)
        p = np.angle(librosa.stft(x, n_fft=N_FFT))
    librosa_write(outfile, x, sr)


def compute_content_loss(a_C, a_G):
    """
    Compute the content cost

    Arguments:
    a_C -- tensor of dimension (1, n_C, n_H, n_W)
    a_G -- tensor of dimension (1, n_C, n_H, n_W)

    Returns:
    J_content -- scalar that you compute using equation 1 above
    """
    m, n_C, n_H, n_W = a_G.shape

    # Reshape a_C and a_G to the (m * n_C, n_H * n_W)
    a_C_unrolled = a_C.view(m * n_C, n_H * n_W)
    a_G_unrolled = a_G.view(m * n_C, n_H * n_W)

    # Compute the cost
    J_content = 1.0 / (4 * m * n_C * n_H * n_W) * torch.sum((a_C_unrolled - a_G_unrolled) ** 2)

    return J_content


def gram(A):
    """
    Argument:
    A -- matrix of shape (n_C, n_L)

    Returns:
    GA -- Gram matrix of shape (n_C, n_C)
    """
    GA = torch.matmul(A, A.t())

    return GA


def gram_over_time_axis(A):
    """
    Argument:
    A -- matrix of shape (1, n_C, n_H, n_W)

    Returns:
    GA -- Gram matrix of A along time axis, of shape (n_C, n_C)
    """
    m, n_C, n_H, n_W = A.shape

    # Reshape the matrix to the shape of (n_C, n_L)
    # Reshape a_C and a_G to the (m * n_C, n_H * n_W)
    A_unrolled = A.view(m * n_C * n_H, n_W)
    GA = torch.matmul(A_unrolled, A_unrolled.t())

    return GA


def compute_layer_style_loss(a_S, a_G):
    """
    Arguments:
    a_S -- tensor of dimension (1, n_C, n_H, n_W)
    a_G -- tensor of dimension (1, n_C, n_H, n_W)

    Returns:
    J_style_layer -- tensor representing a scalar style cost.
    """
    m, n_C, n_H, n_W = a_G.shape

    # Reshape the matrix to the shape of (n_C, n_L)
    # Reshape a_C and a_G to the (m * n_C, n_H * n_W)

    # Calculate the gram
    # !!!!!! IMPORTANT !!!!! Here we compute the Gram along n_C,
    # not along n_H * n_W. But is the result the same? No.
    GS = gram_over_time_axis(a_S)
    GG = gram_over_time_axis(a_G)

    # Computing the loss
    J_style_layer = 1.0 / (4 * (n_C ** 2) * (n_H * n_W)) * torch.sum((GS - GG) ** 2)

    return J_style_layer


"""
# Test
test_S = torch.randn(1, 6, 2, 2)
test_G = torch.randn(1, 6, 2, 2)
print(test_S)
print(test_G)
print(compute_layer_style_loss(test_S, test_G))


# Test
test_C = torch.randn(1, 6, 2, 2)
test_G = torch.randn(1, 6, 2, 2)
print(test_C)
print(test_G)
print(compute_content_loss(test_C, test_G))
"""
# Out:
# '\n# Test\ntest_S = torch.randn(1, 6, 2, 2)\ntest_G = torch.randn(1, 6, 2, 2)\nprint(test_S)\nprint(test_G)\nprint(compute_layer_style_loss(test_S, test_G))\n\n\n# Test\ntest_C = torch.randn(1, 6, 2, 2)\ntest_G = torch.randn(1, 6, 2, 2)\nprint(test_C)\nprint(test_G)\nprint(compute_content_loss(test_C, test_G))\n'

# %%
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt
from torch.autograd import Variable
import time
import math
import argparse
cuda = True if torch.cuda.is_available() else False

CONTENT_FILENAME = "content.wav"
STYLE_FILENAME = "style.wav"
num_epochs = 20000
learning_rate = 0.002
style_param = 1
content_param = 1e2
print_every = 10
plot_every = 10


a_content, sr = wav2spectrum(CONTENT_FILENAME)
a_style, sr = wav2spectrum(STYLE_FILENAME)

a_content_torch = torch.from_numpy(a_content)[None, None, :, :]
if cuda:
    a_content_torch = a_content_torch.cuda()
print(a_content_torch.shape)
a_style_torch = torch.from_numpy(a_style)[None, None, :, :]
if cuda:
    a_style_torch = a_style_torch.cuda()
print(a_style_torch.shape)

model = RandomCNN()
model.eval()

a_C_var = Variable(a_content_torch, requires_grad=False).float()
a_S_var = Variable(a_style_torch, requires_grad=False).float()
if cuda:
    model = model.cuda()
    a_C_var = a_C_var.cuda()
    a_S_var = a_S_var.cuda()

a_C = model(a_C_var)
a_S = model(a_S_var)


# Optimizer
a_G_var = Variable(torch.randn(a_content_torch.shape) * 1e-3)
if cuda:
    a_G_var = a_G_var.cuda()
a_G_var.requires_grad = True
optimizer = torch.optim.Adam([a_G_var])

# Keep track of losses for plotting
current_loss = 0
all_losses = []

def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)
# Out:
# torch.Size([1, 1, 257, 574])
# torch.Size([1, 1, 257, 486])

# %%
start = time.time()
# Train the Model
for epoch in range(1, num_epochs + 1):
    optimizer.zero_grad()
    a_G = model(a_G_var)

    content_loss = content_param * compute_content_loss(a_C, a_G)
    style_loss = style_param * compute_layer_style_loss(a_S, a_G)
    loss = content_loss + style_loss
    loss.backward()
    optimizer.step()

    # print
    if epoch % print_every == 0:
        print("{} {}% {} content_loss:{:4f} style_loss:{:4f} total_loss:{:4f}".format(epoch,
                                                                                      epoch / num_epochs * 100,
                                                                                      timeSince(start),
                                                                                      content_loss.item(),
                                                                                      style_loss.item(), loss.item()))
        current_loss += loss.item()

    # Add current loss avg to list of losses
    if epoch % plot_every == 0:
        all_losses.append(current_loss / plot_every)
        current_loss = 0


gen_spectrum = a_G_var.cpu().data.numpy().squeeze()
gen_audio_C = "output" + ".wav"
spectrum2wav(gen_spectrum, sr, gen_audio_C)

plt.figure()
plt.plot(all_losses)
plt.savefig('loss_curve.png')

plt.figure(figsize=(5, 5))
# we then use the 2nd column.
plt.subplot(1, 1, 1)
plt.title("Content Spectrum")
plt.imsave('Content_Spectrum.png', a_content[:400, :])

plt.figure(figsize=(5, 5))
# we then use the 2nd column.
plt.subplot(1, 1, 1)
plt.title("Style Spectrum")
plt.imsave('Style_Spectrum.png', a_style[:400, :])

plt.figure(figsize=(5, 5))
# we then use the 2nd column.
plt.subplot(1, 1, 1)
plt.title("CNN Voice Transfer Result")
plt.imsave('Gen_Spectrum.png', gen_spectrum[:400, :])
# Out:
# 10 0.05% 0m 0s content_loss:1.040518 style_loss:16.725380 total_loss:17.765898
# 20 0.1% 0m 1s content_loss:1.008882 style_loss:16.591064 total_loss:17.599947
# 30 0.15% 0m 2s content_loss:0.982989 style_loss:16.378633 total_loss:17.361622
# 40 0.2% 0m 3s content_loss:0.954500 style_loss:16.111820 total_loss:17.066320
# 50 0.25% 0m 4s content_loss:0.923532 style_loss:15.781862 total_loss:16.705395
# 60 0.3% 0m 5s content_loss:0.895228 style_loss:15.391537 total_loss:16.286766
# 70 0.35000000000000003% 0m 6s content_loss:0.870754 style_loss:14.957242 total_loss:15.827996
# 80 0.4% 0m 7s content_loss:0.849266 style_loss:14.497105 total_loss:15.346371
# 90 0.44999999999999996% 0m 8s content_loss:0.829689 style_loss:14.025476 total_loss:14.855165
# 100 0.5% 0m 9s content_loss:0.811189 style_loss:13.550931 total_loss:14.362120
# 110 0.5499999999999999% 0m 10s content_loss:0.793403 style_loss:13.077056 total_loss:13.870459
# 120 0.6% 0m 11s content_loss:0.776273 style_loss:12.605228 total_loss:13.381501
# 130 0.65% 0m 12s content_loss:0.759799 style_loss:12.136153 total_loss:12.895952
# 140 0.7000000000000001% 0m 13s content_loss:0.744017 style_loss:11.670444 total_loss:12.414461
# 150 0.75% 0m 14s content_loss:0.729013 style_loss:11.208771 total_loss:11.937784
# 160 0.8% 0m 15s content_loss:0.714876 style_loss:10.751985 total_loss:11.466861
# 170 0.8500000000000001% 0m 16s content_loss:0.701668 style_loss:10.300735 total_loss:11.002402
# 180 0.8999999999999999% 0m 17s content_loss:0.689435 style_loss:9.856240 total_loss:10.545675
# 190 0.95% 0m 19s content_loss:0.678155 style_loss:9.420106 total_loss:10.098261
# 200 1.0% 0m 20s content_loss:0.667771 style_loss:8.993801 total_loss:9.661572
# 210 1.05% 0m 21s content_loss:0.658217 style_loss:8.578390 total_loss:9.236607
# 220 1.0999999999999999% 0m 22s content_loss:0.649478 style_loss:8.173711 total_loss:8.823189
# 230 1.15% 0m 23s content_loss:0.641543 style_loss:7.779602 total_loss:8.421144
# 240 1.2% 0m 24s content_loss:0.634321 style_loss:7.398054 total_loss:8.032375
# 250 1.25% 0m 25s content_loss:0.627736 style_loss:7.030450 total_loss:7.658187
# 260 1.3% 0m 26s content_loss:0.621714 style_loss:6.677660 total_loss:7.299374
# 270 1.35% 0m 27s content_loss:0.616190 style_loss:6.339962 total_loss:6.956152
# 280 1.4000000000000001% 0m 28s content_loss:0.611114 style_loss:6.017107 total_loss:6.628221
# 290 1.4500000000000002% 0m 29s content_loss:0.606443 style_loss:5.708931 total_loss:6.315374
# 300 1.5% 0m 30s content_loss:0.602126 style_loss:5.414392 total_loss:6.016519
# 310 1.55% 0m 31s content_loss:0.598146 style_loss:5.133868 total_loss:5.732014
# 320 1.6% 0m 32s content_loss:0.594489 style_loss:4.867353 total_loss:5.461842
# 330 1.6500000000000001% 0m 33s content_loss:0.591132 style_loss:4.614540 total_loss:5.205672
# 340 1.7000000000000002% 0m 34s content_loss:0.588043 style_loss:4.375099 total_loss:4.963142
# 350 1.7500000000000002% 0m 35s content_loss:0.585177 style_loss:4.148541 total_loss:4.733717
# 360 1.7999999999999998% 0m 37s content_loss:0.582488 style_loss:3.934135 total_loss:4.516623
# 370 1.8499999999999999% 0m 38s content_loss:0.579960 style_loss:3.731457 total_loss:4.311418
# 380 1.9% 0m 39s content_loss:0.577586 style_loss:3.539996 total_loss:4.117582
# 390 1.95% 0m 40s content_loss:0.575353 style_loss:3.359274 total_loss:3.934626
# 400 2.0% 0m 41s content_loss:0.573248 style_loss:3.188780 total_loss:3.762027
# 410 2.0500000000000003% 0m 42s content_loss:0.571252 style_loss:3.027761 total_loss:3.599013
# 420 2.1% 0m 43s content_loss:0.569352 style_loss:2.875713 total_loss:3.445065
# 430 2.15% 0m 44s content_loss:0.567545 style_loss:2.732275 total_loss:3.299820
# 440 2.1999999999999997% 0m 45s content_loss:0.565823 style_loss:2.597028 total_loss:3.162852
# 450 2.25% 0m 46s content_loss:0.564180 style_loss:2.469548 total_loss:3.033728
# 460 2.3% 0m 47s content_loss:0.562609 style_loss:2.349384 total_loss:2.911994
# 470 2.35% 0m 48s content_loss:0.561100 style_loss:2.236120 total_loss:2.797220
# 480 2.4% 0m 49s content_loss:0.559643 style_loss:2.129338 total_loss:2.688981
# 490 2.45% 0m 50s content_loss:0.558237 style_loss:2.028759 total_loss:2.586996
# 500 2.5% 0m 51s content_loss:0.556874 style_loss:1.933970 total_loss:2.490844
# 510 2.55% 0m 52s content_loss:0.555544 style_loss:1.844661 total_loss:2.400205
# 520 2.6% 0m 53s content_loss:0.554242 style_loss:1.760601 total_loss:2.314843
# 530 2.65% 0m 54s content_loss:0.552964 style_loss:1.681492 total_loss:2.234456
# 540 2.7% 0m 55s content_loss:0.551706 style_loss:1.607026 total_loss:2.158732
# 550 2.75% 0m 56s content_loss:0.550464 style_loss:1.536910 total_loss:2.087373
# 560 2.8000000000000003% 0m 57s content_loss:0.549235 style_loss:1.470880 total_loss:2.020115
# 570 2.85% 0m 58s content_loss:0.548017 style_loss:1.408682 total_loss:1.956699
# 580 2.9000000000000004% 0m 59s content_loss:0.546806 style_loss:1.350085 total_loss:1.896890
# 590 2.9499999999999997% 1m 0s content_loss:0.545599 style_loss:1.294852 total_loss:1.840451
# 600 3.0% 1m 1s content_loss:0.544390 style_loss:1.242678 total_loss:1.787068
# 610 3.05% 1m 2s content_loss:0.543171 style_loss:1.193300 total_loss:1.736471
# 620 3.1% 1m 3s content_loss:0.541946 style_loss:1.146588 total_loss:1.688534
# 630 3.15% 1m 4s content_loss:0.540713 style_loss:1.102405 total_loss:1.643118
# 640 3.2% 1m 5s content_loss:0.539476 style_loss:1.060634 total_loss:1.600111
# 650 3.25% 1m 6s content_loss:0.538234 style_loss:1.020941 total_loss:1.559174
# 660 3.3000000000000003% 1m 7s content_loss:0.536978 style_loss:0.982965 total_loss:1.519943
# 670 3.35% 1m 8s content_loss:0.535713 style_loss:0.946814 total_loss:1.482527
# 680 3.4000000000000004% 1m 9s content_loss:0.534448 style_loss:0.912507 total_loss:1.446956
# 690 3.45% 1m 10s content_loss:0.533183 style_loss:0.880019 total_loss:1.413203
# 700 3.5000000000000004% 1m 11s content_loss:0.531922 style_loss:0.849286 total_loss:1.381209
# 710 3.55% 1m 12s content_loss:0.530669 style_loss:0.820211 total_loss:1.350880
# 720 3.5999999999999996% 1m 13s content_loss:0.529421 style_loss:0.792719 total_loss:1.322140
# 730 3.65% 1m 14s content_loss:0.528180 style_loss:0.766704 total_loss:1.294885
# 740 3.6999999999999997% 1m 15s content_loss:0.526948 style_loss:0.742084 total_loss:1.269032
# 750 3.75% 1m 16s content_loss:0.525721 style_loss:0.718787 total_loss:1.244508
# 760 3.8% 1m 17s content_loss:0.524500 style_loss:0.696749 total_loss:1.221249
# 770 3.85% 1m 18s content_loss:0.523285 style_loss:0.675919 total_loss:1.199204
# 780 3.9% 1m 19s content_loss:0.522078 style_loss:0.656229 total_loss:1.178307
# 790 3.95% 1m 20s content_loss:0.520878 style_loss:0.637596 total_loss:1.158473
# 800 4.0% 1m 21s content_loss:0.519684 style_loss:0.619901 total_loss:1.139586
# 810 4.05% 1m 22s content_loss:0.518499 style_loss:0.603108 total_loss:1.121606
# 820 4.1000000000000005% 1m 23s content_loss:0.517322 style_loss:0.587177 total_loss:1.104499
# 830 4.15% 1m 24s content_loss:0.516153 style_loss:0.572056 total_loss:1.088209
# 840 4.2% 1m 25s content_loss:0.514993 style_loss:0.557692 total_loss:1.072685
# 850 4.25% 1m 26s content_loss:0.513844 style_loss:0.544042 total_loss:1.057885
# 860 4.3% 1m 27s content_loss:0.512705 style_loss:0.531072 total_loss:1.043777
# 870 4.35% 1m 28s content_loss:0.511578 style_loss:0.518758 total_loss:1.030336
# 880 4.3999999999999995% 1m 29s content_loss:0.510463 style_loss:0.507061 total_loss:1.017525
# 890 4.45% 1m 30s content_loss:0.509361 style_loss:0.495945 total_loss:1.005306
# 900 4.5% 1m 31s content_loss:0.508272 style_loss:0.485375 total_loss:0.993646
# 910 4.55% 1m 32s content_loss:0.507194 style_loss:0.475306 total_loss:0.982500
# 920 4.6% 1m 33s content_loss:0.506128 style_loss:0.465703 total_loss:0.971831
# 930 4.65% 1m 34s content_loss:0.505074 style_loss:0.456532 total_loss:0.961606
# 940 4.7% 1m 35s content_loss:0.504031 style_loss:0.447758 total_loss:0.951789
# 950 4.75% 1m 36s content_loss:0.502996 style_loss:0.439359 total_loss:0.942355
# 960 4.8% 1m 37s content_loss:0.501972 style_loss:0.431305 total_loss:0.933277
# 970 4.8500000000000005% 1m 38s content_loss:0.500954 style_loss:0.423584 total_loss:0.924538
# 980 4.9% 1m 39s content_loss:0.499944 style_loss:0.416180 total_loss:0.916124
# 990 4.95% 1m 40s content_loss:0.498943 style_loss:0.409085 total_loss:0.908028
# 1000 5.0% 1m 41s content_loss:0.497949 style_loss:0.402255 total_loss:0.900204
# 1010 5.050000000000001% 1m 42s content_loss:0.496963 style_loss:0.395607 total_loss:0.892571
# 1020 5.1% 1m 43s content_loss:0.495982 style_loss:0.389116 total_loss:0.885099
# 1030 5.1499999999999995% 1m 44s content_loss:0.495010 style_loss:0.382809 total_loss:0.877819
# 1040 5.2% 1m 45s content_loss:0.494048 style_loss:0.376705 total_loss:0.870752
# 1050 5.25% 1m 46s content_loss:0.493096 style_loss:0.370800 total_loss:0.863897
# 1060 5.3% 1m 47s content_loss:0.492158 style_loss:0.365084 total_loss:0.857242
# 1070 5.35% 1m 48s content_loss:0.491230 style_loss:0.359547 total_loss:0.850778
# 1080 5.4% 1m 49s content_loss:0.490313 style_loss:0.354183 total_loss:0.844495
# 1090 5.45% 1m 50s content_loss:0.489406 style_loss:0.348974 total_loss:0.838380
# 1100 5.5% 1m 51s content_loss:0.488510 style_loss:0.343908 total_loss:0.832418
# 1110 5.55% 1m 52s content_loss:0.487623 style_loss:0.338976 total_loss:0.826599
# 1120 5.6000000000000005% 1m 53s content_loss:0.486748 style_loss:0.334165 total_loss:0.820913
# 1130 5.65% 1m 54s content_loss:0.485882 style_loss:0.329470 total_loss:0.815352
# 1140 5.7% 1m 55s content_loss:0.485025 style_loss:0.324880 total_loss:0.809906
# 1150 5.75% 1m 56s content_loss:0.484180 style_loss:0.320387 total_loss:0.804567
# 1160 5.800000000000001% 1m 57s content_loss:0.483342 style_loss:0.315982 total_loss:0.799324
# 1170 5.8500000000000005% 1m 58s content_loss:0.482513 style_loss:0.311650 total_loss:0.794163
# 1180 5.8999999999999995% 2m 0s content_loss:0.481693 style_loss:0.307383 total_loss:0.789076
# 1190 5.949999999999999% 2m 1s content_loss:0.480881 style_loss:0.303177 total_loss:0.784058
# 1200 6.0% 2m 2s content_loss:0.480079 style_loss:0.299030 total_loss:0.779109
# 1210 6.05% 2m 3s content_loss:0.479283 style_loss:0.294945 total_loss:0.774228
# 1220 6.1% 2m 4s content_loss:0.478496 style_loss:0.290916 total_loss:0.769411
# 1230 6.15% 2m 5s content_loss:0.477717 style_loss:0.286938 total_loss:0.764656
# 1240 6.2% 2m 6s content_loss:0.476950 style_loss:0.283009 total_loss:0.759959
# 1250 6.25% 2m 7s content_loss:0.476191 style_loss:0.279126 total_loss:0.755318
# 1260 6.3% 2m 8s content_loss:0.475441 style_loss:0.275290 total_loss:0.750731
# 1270 6.35% 2m 9s content_loss:0.474698 style_loss:0.271501 total_loss:0.746198
# 1280 6.4% 2m 10s content_loss:0.473964 style_loss:0.267753 total_loss:0.741717
# 1290 6.45% 2m 11s content_loss:0.473238 style_loss:0.264045 total_loss:0.737283
# 1300 6.5% 2m 12s content_loss:0.472520 style_loss:0.260375 total_loss:0.732895
# 1310 6.550000000000001% 2m 13s content_loss:0.471809 style_loss:0.256743 total_loss:0.728551
# 1320 6.6000000000000005% 2m 14s content_loss:0.471107 style_loss:0.253145 total_loss:0.724252
# 1330 6.65% 2m 15s content_loss:0.470415 style_loss:0.249577 total_loss:0.719992
# 1340 6.7% 2m 16s content_loss:0.469731 style_loss:0.246040 total_loss:0.715771
# 1350 6.75% 2m 17s content_loss:0.469057 style_loss:0.242531 total_loss:0.711588
# 1360 6.800000000000001% 2m 18s content_loss:0.468392 style_loss:0.239053 total_loss:0.707445
# 1370 6.8500000000000005% 2m 19s content_loss:0.467736 style_loss:0.235612 total_loss:0.703348
# 1380 6.9% 2m 20s content_loss:0.467088 style_loss:0.232206 total_loss:0.699294
# 1390 6.950000000000001% 2m 21s content_loss:0.466449 style_loss:0.228830 total_loss:0.695280
# 1400 7.000000000000001% 2m 22s content_loss:0.465819 style_loss:0.225484 total_loss:0.691303
# 1410 7.049999999999999% 2m 23s content_loss:0.465197 style_loss:0.222169 total_loss:0.687367
# 1420 7.1% 2m 24s content_loss:0.464584 style_loss:0.218886 total_loss:0.683470
# 1430 7.1499999999999995% 2m 25s content_loss:0.463978 style_loss:0.215636 total_loss:0.679614
# 1440 7.199999999999999% 2m 26s content_loss:0.463378 style_loss:0.212420 total_loss:0.675799
# 1450 7.249999999999999% 2m 27s content_loss:0.462788 style_loss:0.209235 total_loss:0.672023
# 1460 7.3% 2m 28s content_loss:0.462207 style_loss:0.206080 total_loss:0.668287
# 1470 7.35% 2m 29s content_loss:0.461634 style_loss:0.202960 total_loss:0.664594
# 1480 7.3999999999999995% 2m 30s content_loss:0.461070 style_loss:0.199874 total_loss:0.660944
# 1490 7.449999999999999% 2m 31s content_loss:0.460512 style_loss:0.196826 total_loss:0.657339
# 1500 7.5% 2m 32s content_loss:0.459961 style_loss:0.193818 total_loss:0.653780
# 1510 7.55% 2m 33s content_loss:0.459418 style_loss:0.190847 total_loss:0.650265
# 1520 7.6% 2m 34s content_loss:0.458880 style_loss:0.187915 total_loss:0.646795
# 1530 7.6499999999999995% 2m 35s content_loss:0.458349 style_loss:0.185021 total_loss:0.643370
# 1540 7.7% 2m 36s content_loss:0.457823 style_loss:0.182167 total_loss:0.639990
# 1550 7.75% 2m 37s content_loss:0.457303 style_loss:0.179352 total_loss:0.636655
# 1560 7.8% 2m 38s content_loss:0.456788 style_loss:0.176578 total_loss:0.633366
# 1570 7.85% 2m 39s content_loss:0.456281 style_loss:0.173841 total_loss:0.630121
# 1580 7.9% 2m 40s content_loss:0.455778 style_loss:0.171144 total_loss:0.626921
# 1590 7.95% 2m 41s content_loss:0.455280 style_loss:0.168483 total_loss:0.623762
# 1600 8.0% 2m 42s content_loss:0.454786 style_loss:0.165860 total_loss:0.620646
# 1610 8.05% 2m 43s content_loss:0.454297 style_loss:0.163276 total_loss:0.617573
# 1620 8.1% 2m 44s content_loss:0.453811 style_loss:0.160729 total_loss:0.614541
# 1630 8.15% 2m 45s content_loss:0.453328 style_loss:0.158220 total_loss:0.611548
# 1640 8.200000000000001% 2m 46s content_loss:0.452847 style_loss:0.155750 total_loss:0.608597
# 1650 8.25% 2m 47s content_loss:0.452369 style_loss:0.153320 total_loss:0.605689
# 1660 8.3% 2m 48s content_loss:0.451895 style_loss:0.150928 total_loss:0.602823
# 1670 8.35% 2m 49s content_loss:0.451423 style_loss:0.148574 total_loss:0.599998
# 1680 8.4% 2m 50s content_loss:0.450954 style_loss:0.146261 total_loss:0.597215
# 1690 8.450000000000001% 2m 51s content_loss:0.450488 style_loss:0.143991 total_loss:0.594478
# 1700 8.5% 2m 52s content_loss:0.450022 style_loss:0.141763 total_loss:0.591786
# 1710 8.55% 2m 53s content_loss:0.449558 style_loss:0.139578 total_loss:0.589136
# 1720 8.6% 2m 54s content_loss:0.449094 style_loss:0.137439 total_loss:0.586534
# 1730 8.649999999999999% 2m 55s content_loss:0.448632 style_loss:0.135345 total_loss:0.583977
# 1740 8.7% 2m 56s content_loss:0.448169 style_loss:0.133300 total_loss:0.581469
# 1750 8.75% 2m 57s content_loss:0.447707 style_loss:0.131298 total_loss:0.579006
# 1760 8.799999999999999% 2m 58s content_loss:0.447244 style_loss:0.129344 total_loss:0.576589
# 1770 8.85% 2m 59s content_loss:0.446781 style_loss:0.127436 total_loss:0.574217
# 1780 8.9% 3m 0s content_loss:0.446319 style_loss:0.125569 total_loss:0.571888
# 1790 8.95% 3m 1s content_loss:0.445856 style_loss:0.123748 total_loss:0.569604
# 1800 9.0% 3m 2s content_loss:0.445392 style_loss:0.121970 total_loss:0.567362
# 1810 9.049999999999999% 3m 3s content_loss:0.444928 style_loss:0.120233 total_loss:0.565161
# 1820 9.1% 3m 4s content_loss:0.444466 style_loss:0.118535 total_loss:0.563000
# 1830 9.15% 3m 5s content_loss:0.444001 style_loss:0.116878 total_loss:0.560879
# 1840 9.2% 3m 6s content_loss:0.443536 style_loss:0.115260 total_loss:0.558796
# 1850 9.25% 3m 7s content_loss:0.443069 style_loss:0.113682 total_loss:0.556751
# 1860 9.3% 3m 9s content_loss:0.442599 style_loss:0.112142 total_loss:0.554742
# 1870 9.35% 3m 10s content_loss:0.442130 style_loss:0.110639 total_loss:0.552769
# 1880 9.4% 3m 11s content_loss:0.441658 style_loss:0.109174 total_loss:0.550832
# 1890 9.45% 3m 12s content_loss:0.441184 style_loss:0.107745 total_loss:0.548929
# 1900 9.5% 3m 13s content_loss:0.440707 style_loss:0.106354 total_loss:0.547061
# 1910 9.55% 3m 14s content_loss:0.440229 style_loss:0.104996 total_loss:0.545225
# 1920 9.6% 3m 15s content_loss:0.439750 style_loss:0.103672 total_loss:0.543422
# 1930 9.65% 3m 16s content_loss:0.439269 style_loss:0.102382 total_loss:0.541651
# 1940 9.700000000000001% 3m 17s content_loss:0.438785 style_loss:0.101125 total_loss:0.539910
# 1950 9.75% 3m 18s content_loss:0.438300 style_loss:0.099899 total_loss:0.538198
# 1960 9.8% 3m 19s content_loss:0.437812 style_loss:0.098705 total_loss:0.536517
# 1970 9.85% 3m 20s content_loss:0.437322 style_loss:0.097542 total_loss:0.534865
# 1980 9.9% 3m 21s content_loss:0.436829 style_loss:0.096411 total_loss:0.533240
# 1990 9.950000000000001% 3m 22s content_loss:0.436335 style_loss:0.095309 total_loss:0.531643
# 2000 10.0% 3m 23s content_loss:0.435837 style_loss:0.094234 total_loss:0.530070
# 2010 10.05% 3m 24s content_loss:0.435337 style_loss:0.093184 total_loss:0.528521
# 2020 10.100000000000001% 3m 25s content_loss:0.434834 style_loss:0.092163 total_loss:0.526997
# 2030 10.15% 3m 26s content_loss:0.434329 style_loss:0.091165 total_loss:0.525494
# 2040 10.2% 3m 27s content_loss:0.433821 style_loss:0.090193 total_loss:0.524014
# 2050 10.25% 3m 28s content_loss:0.433311 style_loss:0.089245 total_loss:0.522555
# 2060 10.299999999999999% 3m 29s content_loss:0.432798 style_loss:0.088318 total_loss:0.521116
# 2070 10.35% 3m 30s content_loss:0.432284 style_loss:0.087412 total_loss:0.519696
# 2080 10.4% 3m 31s content_loss:0.431767 style_loss:0.086526 total_loss:0.518293
# 2090 10.45% 3m 32s content_loss:0.431248 style_loss:0.085661 total_loss:0.516909
# 2100 10.5% 3m 33s content_loss:0.430727 style_loss:0.084816 total_loss:0.515543
# 2110 10.549999999999999% 3m 34s content_loss:0.430202 style_loss:0.083990 total_loss:0.514192
# 2120 10.6% 3m 35s content_loss:0.429676 style_loss:0.083182 total_loss:0.512858
# 2130 10.65% 3m 36s content_loss:0.429147 style_loss:0.082393 total_loss:0.511540
# 2140 10.7% 3m 37s content_loss:0.428616 style_loss:0.081622 total_loss:0.510238
# 2150 10.75% 3m 38s content_loss:0.428082 style_loss:0.080868 total_loss:0.508950
# 2160 10.8% 3m 39s content_loss:0.427545 style_loss:0.080131 total_loss:0.507677
# 2170 10.85% 3m 40s content_loss:0.427005 style_loss:0.079413 total_loss:0.506418
# 2180 10.9% 3m 41s content_loss:0.426461 style_loss:0.078711 total_loss:0.505173
# 2190 10.95% 3m 42s content_loss:0.425916 style_loss:0.078025 total_loss:0.503941
# 2200 11.0% 3m 43s content_loss:0.425369 style_loss:0.077352 total_loss:0.502722
# 2210 11.05% 3m 44s content_loss:0.424820 style_loss:0.076695 total_loss:0.501515
# 2220 11.1% 3m 45s content_loss:0.424268 style_loss:0.076052 total_loss:0.500320
# 2230 11.15% 3m 46s content_loss:0.423713 style_loss:0.075425 total_loss:0.499138
# 2240 11.200000000000001% 3m 47s content_loss:0.423156 style_loss:0.074812 total_loss:0.497968
# 2250 11.25% 3m 48s content_loss:0.422596 style_loss:0.074214 total_loss:0.496810
# 2260 11.3% 3m 49s content_loss:0.422035 style_loss:0.073627 total_loss:0.495662
# 2270 11.35% 3m 50s content_loss:0.421472 style_loss:0.073053 total_loss:0.494525
# 2280 11.4% 3m 51s content_loss:0.420908 style_loss:0.072491 total_loss:0.493399
# 2290 11.450000000000001% 3m 52s content_loss:0.420343 style_loss:0.071940 total_loss:0.492283
# 2300 11.5% 3m 53s content_loss:0.419776 style_loss:0.071401 total_loss:0.491176
# 2310 11.55% 3m 54s content_loss:0.419207 style_loss:0.070873 total_loss:0.490080
# 2320 11.600000000000001% 3m 55s content_loss:0.418636 style_loss:0.070356 total_loss:0.488992
# 2330 11.65% 3m 56s content_loss:0.418063 style_loss:0.069850 total_loss:0.487913
# 2340 11.700000000000001% 3m 57s content_loss:0.417489 style_loss:0.069355 total_loss:0.486843
# 2350 11.75% 3m 58s content_loss:0.416913 style_loss:0.068868 total_loss:0.485782
# 2360 11.799999999999999% 3m 59s content_loss:0.416334 style_loss:0.068395 total_loss:0.484729
# 2370 11.85% 4m 0s content_loss:0.415755 style_loss:0.067929 total_loss:0.483684
# 2380 11.899999999999999% 4m 1s content_loss:0.415174 style_loss:0.067474 total_loss:0.482647
# 2390 11.95% 4m 2s content_loss:0.414591 style_loss:0.067028 total_loss:0.481619
# 2400 12.0% 4m 3s content_loss:0.414007 style_loss:0.066591 total_loss:0.480598
# 2410 12.049999999999999% 4m 4s content_loss:0.413423 style_loss:0.066162 total_loss:0.479585
# 2420 12.1% 4m 5s content_loss:0.412836 style_loss:0.065743 total_loss:0.478580
# 2430 12.15% 4m 6s content_loss:0.412250 style_loss:0.065332 total_loss:0.477581
# 2440 12.2% 4m 7s content_loss:0.411660 style_loss:0.064930 total_loss:0.476590
# 2450 12.25% 4m 8s content_loss:0.411070 style_loss:0.064536 total_loss:0.475606
# 2460 12.3% 4m 9s content_loss:0.410479 style_loss:0.064150 total_loss:0.474629
# 2470 12.35% 4m 10s content_loss:0.409887 style_loss:0.063771 total_loss:0.473658
# 2480 12.4% 4m 11s content_loss:0.409293 style_loss:0.063400 total_loss:0.472693
# 2490 12.45% 4m 12s content_loss:0.408699 style_loss:0.063036 total_loss:0.471735
# 2500 12.5% 4m 13s content_loss:0.408105 style_loss:0.062677 total_loss:0.470782
# 2510 12.55% 4m 14s content_loss:0.407509 style_loss:0.062325 total_loss:0.469834
# 2520 12.6% 4m 15s content_loss:0.406913 style_loss:0.061980 total_loss:0.468893
# 2530 12.65% 4m 16s content_loss:0.406315 style_loss:0.061643 total_loss:0.467958
# 2540 12.7% 4m 17s content_loss:0.405717 style_loss:0.061312 total_loss:0.467029
# 2550 12.75% 4m 18s content_loss:0.405117 style_loss:0.060988 total_loss:0.466105
# 2560 12.8% 4m 19s content_loss:0.404517 style_loss:0.060669 total_loss:0.465186
# 2570 12.85% 4m 20s content_loss:0.403917 style_loss:0.060355 total_loss:0.464272
# 2580 12.9% 4m 21s content_loss:0.403317 style_loss:0.060046 total_loss:0.463363
# 2590 12.950000000000001% 4m 22s content_loss:0.402715 style_loss:0.059744 total_loss:0.462458
# 2600 13.0% 4m 23s content_loss:0.402113 style_loss:0.059446 total_loss:0.461559
# 2610 13.05% 4m 24s content_loss:0.401511 style_loss:0.059153 total_loss:0.460665
# 2620 13.100000000000001% 4m 25s content_loss:0.400908 style_loss:0.058867 total_loss:0.459775
# 2630 13.15% 4m 26s content_loss:0.400305 style_loss:0.058585 total_loss:0.458890
# 2640 13.200000000000001% 4m 28s content_loss:0.399701 style_loss:0.058309 total_loss:0.458010
# 2650 13.25% 4m 29s content_loss:0.399097 style_loss:0.058036 total_loss:0.457134
# 2660 13.3% 4m 30s content_loss:0.398492 style_loss:0.057770 total_loss:0.456262
# 2670 13.350000000000001% 4m 31s content_loss:0.397888 style_loss:0.057508 total_loss:0.455396
# 2680 13.4% 4m 32s content_loss:0.397283 style_loss:0.057250 total_loss:0.454533
# 2690 13.450000000000001% 4m 33s content_loss:0.396677 style_loss:0.056997 total_loss:0.453674
# 2700 13.5% 4m 34s content_loss:0.396071 style_loss:0.056748 total_loss:0.452819
# 2710 13.55% 4m 35s content_loss:0.395465 style_loss:0.056503 total_loss:0.451968
# 2720 13.600000000000001% 4m 36s content_loss:0.394859 style_loss:0.056263 total_loss:0.451121
# 2730 13.65% 4m 37s content_loss:0.394253 style_loss:0.056025 total_loss:0.450278
# 2740 13.700000000000001% 4m 38s content_loss:0.393645 style_loss:0.055794 total_loss:0.449439
# 2750 13.750000000000002% 4m 39s content_loss:0.393039 style_loss:0.055565 total_loss:0.448603
# 2760 13.8% 4m 40s content_loss:0.392432 style_loss:0.055340 total_loss:0.447772
# 2770 13.850000000000001% 4m 41s content_loss:0.391825 style_loss:0.055118 total_loss:0.446943
# 2780 13.900000000000002% 4m 42s content_loss:0.391218 style_loss:0.054899 total_loss:0.446118
# 2790 13.950000000000001% 4m 43s content_loss:0.390611 style_loss:0.054684 total_loss:0.445296
# 2800 14.000000000000002% 4m 44s content_loss:0.390004 style_loss:0.054473 total_loss:0.444477
# 2810 14.05% 4m 45s content_loss:0.389398 style_loss:0.054265 total_loss:0.443662
# 2820 14.099999999999998% 4m 46s content_loss:0.388791 style_loss:0.054059 total_loss:0.442850
# 2830 14.149999999999999% 4m 47s content_loss:0.388184 style_loss:0.053856 total_loss:0.442040
# 2840 14.2% 4m 48s content_loss:0.387579 style_loss:0.053654 total_loss:0.441233
# 2850 14.249999999999998% 4m 49s content_loss:0.386972 style_loss:0.053456 total_loss:0.440428
# 2860 14.299999999999999% 4m 50s content_loss:0.386366 style_loss:0.053260 total_loss:0.439626
# 2870 14.35% 4m 51s content_loss:0.385759 style_loss:0.053067 total_loss:0.438826
# 2880 14.399999999999999% 4m 52s content_loss:0.385153 style_loss:0.052876 total_loss:0.438028
# 2890 14.45% 4m 53s content_loss:0.384546 style_loss:0.052688 total_loss:0.437234
# 2900 14.499999999999998% 4m 54s content_loss:0.383940 style_loss:0.052502 total_loss:0.436442
# 2910 14.549999999999999% 4m 55s content_loss:0.383334 style_loss:0.052319 total_loss:0.435653
# 2920 14.6% 4m 56s content_loss:0.382728 style_loss:0.052138 total_loss:0.434866
# 2930 14.649999999999999% 4m 57s content_loss:0.382121 style_loss:0.051961 total_loss:0.434081
# 2940 14.7% 4m 58s content_loss:0.381515 style_loss:0.051785 total_loss:0.433300
# 2950 14.75% 4m 59s content_loss:0.380909 style_loss:0.051611 total_loss:0.432520
# 2960 14.799999999999999% 5m 0s content_loss:0.380303 style_loss:0.051441 total_loss:0.431744
# 2970 14.85% 5m 1s content_loss:0.379698 style_loss:0.051273 total_loss:0.430971
# 2980 14.899999999999999% 5m 2s content_loss:0.379092 style_loss:0.051108 total_loss:0.430200
# 2990 14.95% 5m 3s content_loss:0.378487 style_loss:0.050945 total_loss:0.429432
# 3000 15.0% 5m 4s content_loss:0.377881 style_loss:0.050785 total_loss:0.428666
# 3010 15.049999999999999% 5m 5s content_loss:0.377277 style_loss:0.050624 total_loss:0.427901
# 3020 15.1% 5m 6s content_loss:0.376673 style_loss:0.050466 total_loss:0.427140
# 3030 15.15% 5m 7s content_loss:0.376071 style_loss:0.050309 total_loss:0.426380
# 3040 15.2% 5m 8s content_loss:0.375469 style_loss:0.050154 total_loss:0.425622
# 3050 15.25% 5m 9s content_loss:0.374866 style_loss:0.050000 total_loss:0.424866
# 3060 15.299999999999999% 5m 10s content_loss:0.374263 style_loss:0.049850 total_loss:0.424113
# 3070 15.35% 5m 11s content_loss:0.373661 style_loss:0.049700 total_loss:0.423361
# 3080 15.4% 5m 12s content_loss:0.373059 style_loss:0.049553 total_loss:0.422612
# 3090 15.45% 5m 13s content_loss:0.372459 style_loss:0.049404 total_loss:0.421863
# 3100 15.5% 5m 14s content_loss:0.371859 style_loss:0.049259 total_loss:0.421118
# 3110 15.55% 5m 15s content_loss:0.371258 style_loss:0.049114 total_loss:0.420372
# 3120 15.6% 5m 16s content_loss:0.370658 style_loss:0.048970 total_loss:0.419628
# 3130 15.65% 5m 17s content_loss:0.370059 style_loss:0.048827 total_loss:0.418886
# 3140 15.7% 5m 18s content_loss:0.369460 style_loss:0.048686 total_loss:0.418146
# 3150 15.75% 5m 19s content_loss:0.368860 style_loss:0.048547 total_loss:0.417407
# 3160 15.8% 5m 20s content_loss:0.368262 style_loss:0.048409 total_loss:0.416671
# 3170 15.85% 5m 21s content_loss:0.367665 style_loss:0.048271 total_loss:0.415936
# 3180 15.9% 5m 22s content_loss:0.367068 style_loss:0.048136 total_loss:0.415204
# 3190 15.950000000000001% 5m 23s content_loss:0.366473 style_loss:0.048001 total_loss:0.414474
# 3200 16.0% 5m 24s content_loss:0.365879 style_loss:0.047864 total_loss:0.413744
# 3210 16.05% 5m 25s content_loss:0.365285 style_loss:0.047730 total_loss:0.413016
# 3220 16.1% 5m 26s content_loss:0.364693 style_loss:0.047596 total_loss:0.412289
# 3230 16.150000000000002% 5m 27s content_loss:0.364101 style_loss:0.047464 total_loss:0.411564
# 3240 16.2% 5m 28s content_loss:0.363509 style_loss:0.047332 total_loss:0.410841
# 3250 16.25% 5m 29s content_loss:0.362919 style_loss:0.047201 total_loss:0.410119
# 3260 16.3% 5m 30s content_loss:0.362327 style_loss:0.047072 total_loss:0.409399
# 3270 16.35% 5m 31s content_loss:0.361738 style_loss:0.046943 total_loss:0.408681
# 3280 16.400000000000002% 5m 32s content_loss:0.361148 style_loss:0.046815 total_loss:0.407963
# 3290 16.45% 5m 33s content_loss:0.360558 style_loss:0.046690 total_loss:0.407249
# 3300 16.5% 5m 34s content_loss:0.359970 style_loss:0.046565 total_loss:0.406535
# 3310 16.55% 5m 35s content_loss:0.359382 style_loss:0.046441 total_loss:0.405823
# 3320 16.6% 5m 36s content_loss:0.358795 style_loss:0.046319 total_loss:0.405113
# 3330 16.650000000000002% 5m 37s content_loss:0.358209 style_loss:0.046196 total_loss:0.404405
# 3340 16.7% 5m 38s content_loss:0.357624 style_loss:0.046075 total_loss:0.403698
# 3350 16.75% 5m 39s content_loss:0.357040 style_loss:0.045952 total_loss:0.402993
# 3360 16.8% 5m 40s content_loss:0.356456 style_loss:0.045833 total_loss:0.402289
# 3370 16.85% 5m 41s content_loss:0.355874 style_loss:0.045713 total_loss:0.401587
# 3380 16.900000000000002% 5m 42s content_loss:0.355293 style_loss:0.045593 total_loss:0.400886
# 3390 16.950000000000003% 5m 43s content_loss:0.354711 style_loss:0.045475 total_loss:0.400186
# 3400 17.0% 5m 44s content_loss:0.354131 style_loss:0.045357 total_loss:0.399488
# 3410 17.05% 5m 45s content_loss:0.353553 style_loss:0.045238 total_loss:0.398791
# 3420 17.1% 5m 46s content_loss:0.352974 style_loss:0.045121 total_loss:0.398095
# 3430 17.150000000000002% 5m 48s content_loss:0.352397 style_loss:0.045004 total_loss:0.397402
# 3440 17.2% 5m 49s content_loss:0.351823 style_loss:0.044886 total_loss:0.396709
# 3450 17.25% 5m 50s content_loss:0.351247 style_loss:0.044772 total_loss:0.396019
# 3460 17.299999999999997% 5m 51s content_loss:0.350674 style_loss:0.044656 total_loss:0.395330
# 3470 17.349999999999998% 5m 52s content_loss:0.350100 style_loss:0.044545 total_loss:0.394644
# 3480 17.4% 5m 53s content_loss:0.349525 style_loss:0.044434 total_loss:0.393959
# 3490 17.45% 5m 54s content_loss:0.348952 style_loss:0.044324 total_loss:0.393276
# 3500 17.5% 5m 55s content_loss:0.348381 style_loss:0.044213 total_loss:0.392594
# 3510 17.549999999999997% 5m 56s content_loss:0.347810 style_loss:0.044103 total_loss:0.391913
# 3520 17.599999999999998% 5m 57s content_loss:0.347239 style_loss:0.043994 total_loss:0.391234
# 3530 17.65% 5m 58s content_loss:0.346670 style_loss:0.043885 total_loss:0.390555
# 3540 17.7% 5m 59s content_loss:0.346100 style_loss:0.043779 total_loss:0.389879
# 3550 17.75% 6m 0s content_loss:0.345532 style_loss:0.043671 total_loss:0.389204
# 3560 17.8% 6m 1s content_loss:0.344964 style_loss:0.043566 total_loss:0.388530
# 3570 17.849999999999998% 6m 2s content_loss:0.344398 style_loss:0.043461 total_loss:0.387859
# 3580 17.9% 6m 3s content_loss:0.343834 style_loss:0.043355 total_loss:0.387189
# 3590 17.95% 6m 4s content_loss:0.343271 style_loss:0.043249 total_loss:0.386520
# 3600 18.0% 6m 5s content_loss:0.342710 style_loss:0.043144 total_loss:0.385853
# 3610 18.05% 6m 6s content_loss:0.342149 style_loss:0.043039 total_loss:0.385188
# 3620 18.099999999999998% 6m 7s content_loss:0.341589 style_loss:0.042936 total_loss:0.384525
# 3630 18.15% 6m 8s content_loss:0.341030 style_loss:0.042833 total_loss:0.383863
# 3640 18.2% 6m 9s content_loss:0.340474 style_loss:0.042729 total_loss:0.383203
# 3650 18.25% 6m 10s content_loss:0.339920 style_loss:0.042624 total_loss:0.382544
# 3660 18.3% 6m 11s content_loss:0.339368 style_loss:0.042519 total_loss:0.381887
# 3670 18.35% 6m 12s content_loss:0.338815 style_loss:0.042415 total_loss:0.381231
# 3680 18.4% 6m 13s content_loss:0.338264 style_loss:0.042312 total_loss:0.380577
# 3690 18.45% 6m 14s content_loss:0.337715 style_loss:0.042209 total_loss:0.379924
# 3700 18.5% 6m 15s content_loss:0.337166 style_loss:0.042107 total_loss:0.379273
# 3710 18.55% 6m 16s content_loss:0.336618 style_loss:0.042005 total_loss:0.378623
# 3720 18.6% 6m 17s content_loss:0.336072 style_loss:0.041904 total_loss:0.377976
# 3730 18.65% 6m 18s content_loss:0.335526 style_loss:0.041805 total_loss:0.377330
# 3740 18.7% 6m 19s content_loss:0.334982 style_loss:0.041705 total_loss:0.376687
# 3750 18.75% 6m 20s content_loss:0.334439 style_loss:0.041605 total_loss:0.376044
# 3760 18.8% 6m 21s content_loss:0.333897 style_loss:0.041506 total_loss:0.375403
# 3770 18.85% 6m 22s content_loss:0.333356 style_loss:0.041408 total_loss:0.374764
# 3780 18.9% 6m 23s content_loss:0.332817 style_loss:0.041310 total_loss:0.374127
# 3790 18.95% 6m 24s content_loss:0.332280 style_loss:0.041212 total_loss:0.373491
# 3800 19.0% 6m 25s content_loss:0.331743 style_loss:0.041114 total_loss:0.372858
# 3810 19.05% 6m 26s content_loss:0.331207 style_loss:0.041019 total_loss:0.372226
# 3820 19.1% 6m 27s content_loss:0.330673 style_loss:0.040924 total_loss:0.371597
# 3830 19.15% 6m 28s content_loss:0.330140 style_loss:0.040829 total_loss:0.370970
# 3840 19.2% 6m 29s content_loss:0.329610 style_loss:0.040734 total_loss:0.370344
# 3850 19.25% 6m 30s content_loss:0.329080 style_loss:0.040640 total_loss:0.369720
# 3860 19.3% 6m 31s content_loss:0.328552 style_loss:0.040546 total_loss:0.369098
# 3870 19.35% 6m 32s content_loss:0.328025 style_loss:0.040454 total_loss:0.368479
# 3880 19.400000000000002% 6m 33s content_loss:0.327500 style_loss:0.040361 total_loss:0.367861
# 3890 19.45% 6m 34s content_loss:0.326978 style_loss:0.040268 total_loss:0.367246
# 3900 19.5% 6m 35s content_loss:0.326457 style_loss:0.040176 total_loss:0.366633
# 3910 19.55% 6m 36s content_loss:0.325938 style_loss:0.040083 total_loss:0.366021
# 3920 19.6% 6m 37s content_loss:0.325419 style_loss:0.039991 total_loss:0.365411
# 3930 19.650000000000002% 6m 38s content_loss:0.324903 style_loss:0.039900 total_loss:0.364803
# 3940 19.7% 6m 39s content_loss:0.324387 style_loss:0.039811 total_loss:0.364198
# 3950 19.75% 6m 40s content_loss:0.323874 style_loss:0.039721 total_loss:0.363594
# 3960 19.8% 6m 41s content_loss:0.323362 style_loss:0.039631 total_loss:0.362993
# 3970 19.85% 6m 42s content_loss:0.322852 style_loss:0.039542 total_loss:0.362394
# 3980 19.900000000000002% 6m 43s content_loss:0.322345 style_loss:0.039451 total_loss:0.361796
# 3990 19.950000000000003% 6m 44s content_loss:0.321837 style_loss:0.039363 total_loss:0.361200
# 4000 20.0% 6m 45s content_loss:0.321332 style_loss:0.039274 total_loss:0.360606
# 4010 20.05% 6m 46s content_loss:0.320829 style_loss:0.039185 total_loss:0.360014
# 4020 20.1% 6m 47s content_loss:0.320325 style_loss:0.039100 total_loss:0.359424
# 4030 20.150000000000002% 6m 48s content_loss:0.319822 style_loss:0.039015 total_loss:0.358837
# 4040 20.200000000000003% 6m 49s content_loss:0.319322 style_loss:0.038929 total_loss:0.358251
# 4050 20.25% 6m 50s content_loss:0.318825 style_loss:0.038842 total_loss:0.357667
# 4060 20.3% 6m 51s content_loss:0.318328 style_loss:0.038757 total_loss:0.357086
# 4070 20.349999999999998% 6m 52s content_loss:0.317834 style_loss:0.038671 total_loss:0.356506
# 4080 20.4% 6m 53s content_loss:0.317341 style_loss:0.038587 total_loss:0.355928
# 4090 20.45% 6m 54s content_loss:0.316849 style_loss:0.038504 total_loss:0.355352
# 4100 20.5% 6m 55s content_loss:0.316359 style_loss:0.038420 total_loss:0.354779
# 4110 20.549999999999997% 6m 56s content_loss:0.315871 style_loss:0.038337 total_loss:0.354208
# 4120 20.599999999999998% 6m 57s content_loss:0.315385 style_loss:0.038255 total_loss:0.353640
# 4130 20.65% 6m 58s content_loss:0.314899 style_loss:0.038174 total_loss:0.353073
# 4140 20.7% 6m 59s content_loss:0.314415 style_loss:0.038094 total_loss:0.352509
# 4150 20.75% 7m 0s content_loss:0.313934 style_loss:0.038012 total_loss:0.351947
# 4160 20.8% 7m 1s content_loss:0.313453 style_loss:0.037934 total_loss:0.351387
# 4170 20.849999999999998% 7m 2s content_loss:0.312973 style_loss:0.037856 total_loss:0.350829
# 4180 20.9% 7m 3s content_loss:0.312494 style_loss:0.037779 total_loss:0.350274
# 4190 20.95% 7m 4s content_loss:0.312019 style_loss:0.037701 total_loss:0.349720
# 4200 21.0% 7m 5s content_loss:0.311544 style_loss:0.037624 total_loss:0.349169
# 4210 21.05% 7m 6s content_loss:0.311073 style_loss:0.037547 total_loss:0.348621
# 4220 21.099999999999998% 7m 7s content_loss:0.310604 style_loss:0.037471 total_loss:0.348075
# 4230 21.15% 7m 9s content_loss:0.310137 style_loss:0.037396 total_loss:0.347532
# 4240 21.2% 7m 10s content_loss:0.309672 style_loss:0.037320 total_loss:0.346992
# 4250 21.25% 7m 11s content_loss:0.309207 style_loss:0.037248 total_loss:0.346455
# 4260 21.3% 7m 12s content_loss:0.308744 style_loss:0.037175 total_loss:0.345920
# 4270 21.349999999999998% 7m 13s content_loss:0.308285 style_loss:0.037103 total_loss:0.345387
# 4280 21.4% 7m 14s content_loss:0.307827 style_loss:0.037030 total_loss:0.344857
# 4290 21.45% 7m 15s content_loss:0.307371 style_loss:0.036958 total_loss:0.344329
# 4300 21.5% 7m 16s content_loss:0.306918 style_loss:0.036886 total_loss:0.343804
# 4310 21.55% 7m 17s content_loss:0.306466 style_loss:0.036815 total_loss:0.343281
# 4320 21.6% 7m 18s content_loss:0.306016 style_loss:0.036745 total_loss:0.342760
# 4330 21.65% 7m 19s content_loss:0.305566 style_loss:0.036676 total_loss:0.342242
# 4340 21.7% 7m 20s content_loss:0.305119 style_loss:0.036608 total_loss:0.341727
# 4350 21.75% 7m 21s content_loss:0.304673 style_loss:0.036541 total_loss:0.341214
# 4360 21.8% 7m 22s content_loss:0.304229 style_loss:0.036474 total_loss:0.340703
# 4370 21.85% 7m 23s content_loss:0.303786 style_loss:0.036409 total_loss:0.340195
# 4380 21.9% 7m 24s content_loss:0.303347 style_loss:0.036343 total_loss:0.339689
# 4390 21.95% 7m 25s content_loss:0.302910 style_loss:0.036276 total_loss:0.339186
# 4400 22.0% 7m 26s content_loss:0.302474 style_loss:0.036211 total_loss:0.338685
# 4410 22.05% 7m 27s content_loss:0.302040 style_loss:0.036146 total_loss:0.338186
# 4420 22.1% 7m 28s content_loss:0.301609 style_loss:0.036080 total_loss:0.337689
# 4430 22.15% 7m 29s content_loss:0.301179 style_loss:0.036016 total_loss:0.337196
# 4440 22.2% 7m 30s content_loss:0.300753 style_loss:0.035951 total_loss:0.336704
# 4450 22.25% 7m 31s content_loss:0.300328 style_loss:0.035888 total_loss:0.336216
# 4460 22.3% 7m 32s content_loss:0.299903 style_loss:0.035827 total_loss:0.335729
# 4470 22.35% 7m 33s content_loss:0.299482 style_loss:0.035763 total_loss:0.335245
# 4480 22.400000000000002% 7m 34s content_loss:0.299063 style_loss:0.035701 total_loss:0.334764
# 4490 22.45% 7m 35s content_loss:0.298646 style_loss:0.035639 total_loss:0.334285
# 4500 22.5% 7m 36s content_loss:0.298230 style_loss:0.035577 total_loss:0.333808
# 4510 22.55% 7m 37s content_loss:0.297817 style_loss:0.035516 total_loss:0.333333
# 4520 22.6% 7m 38s content_loss:0.297405 style_loss:0.035456 total_loss:0.332861
# 4530 22.650000000000002% 7m 39s content_loss:0.296996 style_loss:0.035396 total_loss:0.332392
# 4540 22.7% 7m 40s content_loss:0.296587 style_loss:0.035339 total_loss:0.331925
# 4550 22.75% 7m 41s content_loss:0.296181 style_loss:0.035280 total_loss:0.331461
# 4560 22.8% 7m 42s content_loss:0.295776 style_loss:0.035223 total_loss:0.330999
# 4570 22.85% 7m 43s content_loss:0.295374 style_loss:0.035165 total_loss:0.330539
# 4580 22.900000000000002% 7m 44s content_loss:0.294973 style_loss:0.035109 total_loss:0.330082
# 4590 22.95% 7m 45s content_loss:0.294574 style_loss:0.035053 total_loss:0.329627
# 4600 23.0% 7m 46s content_loss:0.294176 style_loss:0.034999 total_loss:0.329175
# 4610 23.05% 7m 47s content_loss:0.293781 style_loss:0.034945 total_loss:0.328725
# 4620 23.1% 7m 48s content_loss:0.293387 style_loss:0.034891 total_loss:0.328279
# 4630 23.150000000000002% 7m 49s content_loss:0.292995 style_loss:0.034839 total_loss:0.327834
# 4640 23.200000000000003% 7m 50s content_loss:0.292605 style_loss:0.034788 total_loss:0.327393
# 4650 23.25% 7m 51s content_loss:0.292219 style_loss:0.034735 total_loss:0.326954
# 4660 23.3% 7m 52s content_loss:0.291834 style_loss:0.034683 total_loss:0.326517
# 4670 23.35% 7m 53s content_loss:0.291451 style_loss:0.034632 total_loss:0.326083
# 4680 23.400000000000002% 7m 54s content_loss:0.291071 style_loss:0.034580 total_loss:0.325651
# 4690 23.45% 7m 55s content_loss:0.290694 style_loss:0.034529 total_loss:0.325223
# 4700 23.5% 7m 56s content_loss:0.290317 style_loss:0.034479 total_loss:0.324796
# 4710 23.549999999999997% 7m 57s content_loss:0.289940 style_loss:0.034432 total_loss:0.324373
# 4720 23.599999999999998% 7m 58s content_loss:0.289569 style_loss:0.034383 total_loss:0.323952
# 4730 23.65% 7m 59s content_loss:0.289198 style_loss:0.034335 total_loss:0.323533
# 4740 23.7% 8m 0s content_loss:0.288830 style_loss:0.034287 total_loss:0.323117
# 4750 23.75% 8m 1s content_loss:0.288463 style_loss:0.034240 total_loss:0.322703
# 4760 23.799999999999997% 8m 2s content_loss:0.288099 style_loss:0.034193 total_loss:0.322292
# 4770 23.849999999999998% 8m 3s content_loss:0.287737 style_loss:0.034146 total_loss:0.321883
# 4780 23.9% 8m 4s content_loss:0.287376 style_loss:0.034101 total_loss:0.321477
# 4790 23.95% 8m 5s content_loss:0.287018 style_loss:0.034055 total_loss:0.321073
# 4800 24.0% 8m 6s content_loss:0.286660 style_loss:0.034012 total_loss:0.320672
# 4810 24.05% 8m 7s content_loss:0.286305 style_loss:0.033968 total_loss:0.320273
# 4820 24.099999999999998% 8m 8s content_loss:0.285953 style_loss:0.033924 total_loss:0.319877
# 4830 24.15% 8m 9s content_loss:0.285603 style_loss:0.033881 total_loss:0.319483
# 4840 24.2% 8m 10s content_loss:0.285255 style_loss:0.033836 total_loss:0.319092
# 4850 24.25% 8m 11s content_loss:0.284907 style_loss:0.033796 total_loss:0.318703
# 4860 24.3% 8m 12s content_loss:0.284562 style_loss:0.033755 total_loss:0.318317
# 4870 24.349999999999998% 8m 13s content_loss:0.284220 style_loss:0.033713 total_loss:0.317934
# 4880 24.4% 8m 14s content_loss:0.283878 style_loss:0.033674 total_loss:0.317553
# 4890 24.45% 8m 15s content_loss:0.283540 style_loss:0.033634 total_loss:0.317174
# 4900 24.5% 8m 17s content_loss:0.283204 style_loss:0.033594 total_loss:0.316798
# 4910 24.55% 8m 18s content_loss:0.282870 style_loss:0.033554 total_loss:0.316424
# 4920 24.6% 8m 19s content_loss:0.282538 style_loss:0.033515 total_loss:0.316053
# 4930 24.65% 8m 20s content_loss:0.282210 style_loss:0.033474 total_loss:0.315684
# 4940 24.7% 8m 21s content_loss:0.281883 style_loss:0.033435 total_loss:0.315318
# 4950 24.75% 8m 22s content_loss:0.281557 style_loss:0.033397 total_loss:0.314954
# 4960 24.8% 8m 23s content_loss:0.281233 style_loss:0.033360 total_loss:0.314593
# 4970 24.85% 8m 24s content_loss:0.280912 style_loss:0.033322 total_loss:0.314235
# 4980 24.9% 8m 25s content_loss:0.280593 style_loss:0.033285 total_loss:0.313879
# 4990 24.95% 8m 26s content_loss:0.280275 style_loss:0.033250 total_loss:0.313525
# 5000 25.0% 8m 27s content_loss:0.279961 style_loss:0.033214 total_loss:0.313174
# 5010 25.05% 8m 28s content_loss:0.279648 style_loss:0.033178 total_loss:0.312826
# 5020 25.1% 8m 29s content_loss:0.279336 style_loss:0.033144 total_loss:0.312480
# 5030 25.15% 8m 30s content_loss:0.279027 style_loss:0.033110 total_loss:0.312137
# 5040 25.2% 8m 31s content_loss:0.278721 style_loss:0.033075 total_loss:0.311797
# 5050 25.25% 8m 32s content_loss:0.278417 style_loss:0.033042 total_loss:0.311459
# 5060 25.3% 8m 33s content_loss:0.278116 style_loss:0.033007 total_loss:0.311123
# 5070 25.35% 8m 34s content_loss:0.277817 style_loss:0.032973 total_loss:0.310790
# 5080 25.4% 8m 35s content_loss:0.277518 style_loss:0.032942 total_loss:0.310459
# 5090 25.45% 8m 36s content_loss:0.277222 style_loss:0.032908 total_loss:0.310131
# 5100 25.5% 8m 37s content_loss:0.276930 style_loss:0.032875 total_loss:0.309805
# 5110 25.55% 8m 38s content_loss:0.276639 style_loss:0.032842 total_loss:0.309481
# 5120 25.6% 8m 39s content_loss:0.276349 style_loss:0.032810 total_loss:0.309160
# 5130 25.650000000000002% 8m 40s content_loss:0.276062 style_loss:0.032779 total_loss:0.308841
# 5140 25.7% 8m 41s content_loss:0.275777 style_loss:0.032748 total_loss:0.308525
# 5150 25.75% 8m 42s content_loss:0.275494 style_loss:0.032717 total_loss:0.308211
# 5160 25.8% 8m 43s content_loss:0.275212 style_loss:0.032688 total_loss:0.307900
# 5170 25.85% 8m 44s content_loss:0.274935 style_loss:0.032656 total_loss:0.307590
# 5180 25.900000000000002% 8m 45s content_loss:0.274658 style_loss:0.032625 total_loss:0.307283
# 5190 25.95% 8m 46s content_loss:0.274384 style_loss:0.032594 total_loss:0.306978
# 5200 26.0% 8m 47s content_loss:0.274111 style_loss:0.032565 total_loss:0.306675
# 5210 26.05% 8m 48s content_loss:0.273840 style_loss:0.032536 total_loss:0.306376
# 5220 26.1% 8m 49s content_loss:0.273572 style_loss:0.032507 total_loss:0.306078
# 5230 26.150000000000002% 8m 50s content_loss:0.273306 style_loss:0.032477 total_loss:0.305784
# 5240 26.200000000000003% 8m 51s content_loss:0.273043 style_loss:0.032448 total_loss:0.305491
# 5250 26.25% 8m 52s content_loss:0.272781 style_loss:0.032420 total_loss:0.305201
# 5260 26.3% 8m 53s content_loss:0.272521 style_loss:0.032391 total_loss:0.304912
# 5270 26.35% 8m 54s content_loss:0.272264 style_loss:0.032363 total_loss:0.304627
# 5280 26.400000000000002% 8m 55s content_loss:0.272008 style_loss:0.032336 total_loss:0.304344
# 5290 26.450000000000003% 8m 56s content_loss:0.271755 style_loss:0.032307 total_loss:0.304063
# 5300 26.5% 8m 57s content_loss:0.271504 style_loss:0.032280 total_loss:0.303784
# 5310 26.55% 8m 58s content_loss:0.271255 style_loss:0.032253 total_loss:0.303508
# 5320 26.6% 8m 59s content_loss:0.271008 style_loss:0.032226 total_loss:0.303234
# 5330 26.650000000000002% 9m 0s content_loss:0.270764 style_loss:0.032198 total_loss:0.302962
# 5340 26.700000000000003% 9m 1s content_loss:0.270521 style_loss:0.032172 total_loss:0.302693
# 5350 26.75% 9m 2s content_loss:0.270281 style_loss:0.032145 total_loss:0.302426
# 5360 26.8% 9m 3s content_loss:0.270042 style_loss:0.032120 total_loss:0.302162
# 5370 26.85% 9m 4s content_loss:0.269805 style_loss:0.032094 total_loss:0.301899
# 5380 26.900000000000002% 9m 5s content_loss:0.269570 style_loss:0.032069 total_loss:0.301639
# 5390 26.950000000000003% 9m 6s content_loss:0.269337 style_loss:0.032045 total_loss:0.301382
# 5400 27.0% 9m 7s content_loss:0.269105 style_loss:0.032021 total_loss:0.301126
# 5410 27.05% 9m 8s content_loss:0.268877 style_loss:0.031997 total_loss:0.300874
# 5420 27.1% 9m 9s content_loss:0.268650 style_loss:0.031973 total_loss:0.300623
# 5430 27.150000000000002% 9m 10s content_loss:0.268425 style_loss:0.031949 total_loss:0.300374
# 5440 27.200000000000003% 9m 11s content_loss:0.268201 style_loss:0.031927 total_loss:0.300128
# 5450 27.250000000000004% 9m 12s content_loss:0.267981 style_loss:0.031904 total_loss:0.299884
# 5460 27.3% 9m 13s content_loss:0.267762 style_loss:0.031880 total_loss:0.299642
# 5470 27.35% 9m 14s content_loss:0.267545 style_loss:0.031857 total_loss:0.299402
# 5480 27.400000000000002% 9m 15s content_loss:0.267331 style_loss:0.031834 total_loss:0.299165
# 5490 27.450000000000003% 9m 16s content_loss:0.267117 style_loss:0.031812 total_loss:0.298930
# 5500 27.500000000000004% 9m 17s content_loss:0.266906 style_loss:0.031791 total_loss:0.298697
# 5510 27.55% 9m 18s content_loss:0.266697 style_loss:0.031770 total_loss:0.298467
# 5520 27.6% 9m 19s content_loss:0.266490 style_loss:0.031749 total_loss:0.298239
# 5530 27.650000000000002% 9m 20s content_loss:0.266286 style_loss:0.031727 total_loss:0.298013
# 5540 27.700000000000003% 9m 21s content_loss:0.266083 style_loss:0.031706 total_loss:0.297789
# 5550 27.750000000000004% 9m 22s content_loss:0.265881 style_loss:0.031687 total_loss:0.297568
# 5560 27.800000000000004% 9m 23s content_loss:0.265682 style_loss:0.031666 total_loss:0.297348
# 5570 27.85% 9m 24s content_loss:0.265485 style_loss:0.031645 total_loss:0.297130
# 5580 27.900000000000002% 9m 25s content_loss:0.265290 style_loss:0.031625 total_loss:0.296915
# 5590 27.950000000000003% 9m 26s content_loss:0.265096 style_loss:0.031606 total_loss:0.296702
# 5600 28.000000000000004% 9m 27s content_loss:0.264904 style_loss:0.031586 total_loss:0.296490
# 5610 28.050000000000004% 9m 28s content_loss:0.264715 style_loss:0.031567 total_loss:0.296281
# 5620 28.1% 9m 29s content_loss:0.264527 style_loss:0.031548 total_loss:0.296074
# 5630 28.15% 9m 30s content_loss:0.264341 style_loss:0.031528 total_loss:0.295870
# 5640 28.199999999999996% 9m 32s content_loss:0.264157 style_loss:0.031510 total_loss:0.295667
# 5650 28.249999999999996% 9m 33s content_loss:0.263974 style_loss:0.031493 total_loss:0.295466
# 5660 28.299999999999997% 9m 34s content_loss:0.263794 style_loss:0.031474 total_loss:0.295268
# 5670 28.349999999999998% 9m 35s content_loss:0.263615 style_loss:0.031457 total_loss:0.295072
# 5680 28.4% 9m 36s content_loss:0.263438 style_loss:0.031439 total_loss:0.294877
# 5690 28.449999999999996% 9m 37s content_loss:0.263262 style_loss:0.031422 total_loss:0.294685
# 5700 28.499999999999996% 9m 38s content_loss:0.263089 style_loss:0.031405 total_loss:0.294494
# 5710 28.549999999999997% 9m 39s content_loss:0.262918 style_loss:0.031388 total_loss:0.294305
# 5720 28.599999999999998% 9m 40s content_loss:0.262745 style_loss:0.031374 total_loss:0.294119
# 5730 28.65% 9m 41s content_loss:0.262577 style_loss:0.031357 total_loss:0.293935
# 5740 28.7% 9m 42s content_loss:0.262412 style_loss:0.031340 total_loss:0.293752
# ...
# 18130 90.64999999999999% 30m 38s content_loss:0.251378 style_loss:0.030213 total_loss:0.281591
# 18140 90.7% 30m 39s content_loss:0.251393 style_loss:0.030198 total_loss:0.281591
# 18150 90.75% 30m 40s content_loss:0.251397 style_loss:0.030194 total_loss:0.281591
# 18160 90.8% 30m 41s content_loss:0.251411 style_loss:0.030181 total_loss:0.281592
# 18170 90.85% 30m 42s content_loss:0.251422 style_loss:0.030171 total_loss:0.281593
# 18180 90.9% 30m 43s content_loss:0.251392 style_loss:0.030199 total_loss:0.281591
# 18190 90.95% 30m 44s content_loss:0.251380 style_loss:0.030211 total_loss:0.281591
# 18200 91.0% 30m 45s content_loss:0.251374 style_loss:0.030218 total_loss:0.281592
# 18210 91.05% 30m 46s content_loss:0.251370 style_loss:0.030222 total_loss:0.281592
# 18220 91.10000000000001% 30m 47s content_loss:0.251378 style_loss:0.030214 total_loss:0.281591
# 18230 91.14999999999999% 30m 48s content_loss:0.251381 style_loss:0.030210 total_loss:0.281591
# 18240 91.2% 30m 49s content_loss:0.251372 style_loss:0.030220 total_loss:0.281591
# 18250 91.25% 30m 50s content_loss:0.251361 style_loss:0.030232 total_loss:0.281593
# 18260 91.3% 30m 51s content_loss:0.251382 style_loss:0.030210 total_loss:0.281591
# 18270 91.35% 30m 52s content_loss:0.251395 style_loss:0.030196 total_loss:0.281591
# 18280 91.4% 30m 53s content_loss:0.251397 style_loss:0.030194 total_loss:0.281591
# 18290 91.45% 30m 54s content_loss:0.251412 style_loss:0.030180 total_loss:0.281592
# 18300 91.5% 30m 55s content_loss:0.251431 style_loss:0.030164 total_loss:0.281594
# 18310 91.55% 30m 56s content_loss:0.251383 style_loss:0.030208 total_loss:0.281591
# 18320 91.60000000000001% 30m 57s content_loss:0.251377 style_loss:0.030215 total_loss:0.281592
# 18330 91.64999999999999% 30m 58s content_loss:0.251387 style_loss:0.030203 total_loss:0.281591
# 18340 91.7% 31m 0s content_loss:0.251395 style_loss:0.030195 total_loss:0.281591
# 18350 91.75% 31m 1s content_loss:0.251401 style_loss:0.030190 total_loss:0.281591
# 18360 91.8% 31m 2s content_loss:0.251420 style_loss:0.030174 total_loss:0.281593
# 18370 91.85% 31m 3s content_loss:0.251414 style_loss:0.030179 total_loss:0.281592
# 18380 91.9% 31m 4s content_loss:0.251380 style_loss:0.030212 total_loss:0.281592
# 18390 91.95% 31m 5s content_loss:0.251384 style_loss:0.030207 total_loss:0.281591
# 18400 92.0% 31m 6s content_loss:0.251394 style_loss:0.030196 total_loss:0.281591
# 18410 92.05% 31m 7s content_loss:0.251403 style_loss:0.030188 total_loss:0.281591
# 18420 92.10000000000001% 31m 8s content_loss:0.251415 style_loss:0.030177 total_loss:0.281592
# 18430 92.15% 31m 9s content_loss:0.251418 style_loss:0.030175 total_loss:0.281592
# 18440 92.2% 31m 10s content_loss:0.251398 style_loss:0.030193 total_loss:0.281591
# 18450 92.25% 31m 11s content_loss:0.251387 style_loss:0.030203 total_loss:0.281591
# 18460 92.30000000000001% 31m 12s content_loss:0.251379 style_loss:0.030212 total_loss:0.281591
# 18470 92.35% 31m 13s content_loss:0.251357 style_loss:0.030237 total_loss:0.281594
# 18480 92.4% 31m 14s content_loss:0.251379 style_loss:0.030212 total_loss:0.281591
# 18490 92.45% 31m 15s content_loss:0.251410 style_loss:0.030182 total_loss:0.281592
# 18500 92.5% 31m 16s content_loss:0.251389 style_loss:0.030202 total_loss:0.281591
# 18510 92.55% 31m 17s content_loss:0.251383 style_loss:0.030208 total_loss:0.281591
# 18520 92.60000000000001% 31m 18s content_loss:0.251379 style_loss:0.030212 total_loss:0.281591
# 18530 92.65% 31m 19s content_loss:0.251371 style_loss:0.030221 total_loss:0.281592
# 18540 92.7% 31m 20s content_loss:0.251370 style_loss:0.030222 total_loss:0.281592
# 18550 92.75% 31m 21s content_loss:0.251383 style_loss:0.030208 total_loss:0.281591
# 18560 92.80000000000001% 31m 22s content_loss:0.251387 style_loss:0.030204 total_loss:0.281591
# 18570 92.85% 31m 23s content_loss:0.251383 style_loss:0.030208 total_loss:0.281591
# 18580 92.9% 31m 24s content_loss:0.251359 style_loss:0.030236 total_loss:0.281594
# 18590 92.95% 31m 25s content_loss:0.251376 style_loss:0.030215 total_loss:0.281592
# 18600 93.0% 31m 26s content_loss:0.251408 style_loss:0.030183 total_loss:0.281592
# 18610 93.05% 31m 27s content_loss:0.251395 style_loss:0.030196 total_loss:0.281591
# 18620 93.10000000000001% 31m 28s content_loss:0.251387 style_loss:0.030204 total_loss:0.281591
# 18630 93.15% 31m 29s content_loss:0.251381 style_loss:0.030210 total_loss:0.281591
# 18640 93.2% 31m 30s content_loss:0.251371 style_loss:0.030221 total_loss:0.281592
# 18650 93.25% 31m 31s content_loss:0.251370 style_loss:0.030223 total_loss:0.281593
# 18660 93.30000000000001% 31m 32s content_loss:0.251386 style_loss:0.030204 total_loss:0.281591
# 18670 93.35% 31m 33s content_loss:0.251394 style_loss:0.030196 total_loss:0.281591
# 18680 93.4% 31m 34s content_loss:0.251397 style_loss:0.030194 total_loss:0.281591
# 18690 93.45% 31m 35s content_loss:0.251417 style_loss:0.030175 total_loss:0.281593
# 18700 93.5% 31m 36s content_loss:0.251421 style_loss:0.030172 total_loss:0.281593
# 18710 93.55% 31m 37s content_loss:0.251379 style_loss:0.030212 total_loss:0.281591
# 18720 93.60000000000001% 31m 38s content_loss:0.251383 style_loss:0.030208 total_loss:0.281591
# 18730 93.65% 31m 39s content_loss:0.251392 style_loss:0.030199 total_loss:0.281591
# 18740 93.7% 31m 40s content_loss:0.251399 style_loss:0.030192 total_loss:0.281591
# 18750 93.75% 31m 41s content_loss:0.251411 style_loss:0.030181 total_loss:0.281592
# 18760 93.8% 31m 42s content_loss:0.251425 style_loss:0.030168 total_loss:0.281594
# 18770 93.85% 31m 43s content_loss:0.251393 style_loss:0.030197 total_loss:0.281591
# 18780 93.89999999999999% 31m 44s content_loss:0.251379 style_loss:0.030212 total_loss:0.281591
# 18790 93.95% 31m 45s content_loss:0.251376 style_loss:0.030215 total_loss:0.281591
# 18800 94.0% 31m 46s content_loss:0.251380 style_loss:0.030211 total_loss:0.281591
# 18810 94.05% 31m 47s content_loss:0.251374 style_loss:0.030218 total_loss:0.281592
# 18820 94.1% 31m 48s content_loss:0.251372 style_loss:0.030220 total_loss:0.281592
# 18830 94.15% 31m 49s content_loss:0.251377 style_loss:0.030215 total_loss:0.281592
# 18840 94.19999999999999% 31m 50s content_loss:0.251378 style_loss:0.030213 total_loss:0.281591
# 18850 94.25% 31m 51s content_loss:0.251374 style_loss:0.030218 total_loss:0.281592
# 18860 94.3% 31m 52s content_loss:0.251369 style_loss:0.030223 total_loss:0.281592
# 18870 94.35% 31m 53s content_loss:0.251378 style_loss:0.030213 total_loss:0.281591
# 18880 94.39999999999999% 31m 54s content_loss:0.251383 style_loss:0.030208 total_loss:0.281591
# 18890 94.45% 31m 55s content_loss:0.251380 style_loss:0.030211 total_loss:0.281591
# 18900 94.5% 31m 56s content_loss:0.251364 style_loss:0.030229 total_loss:0.281593
# 18910 94.55% 31m 57s content_loss:0.251372 style_loss:0.030219 total_loss:0.281592
# 18920 94.6% 31m 58s content_loss:0.251397 style_loss:0.030194 total_loss:0.281591
# 18930 94.65% 31m 59s content_loss:0.251402 style_loss:0.030189 total_loss:0.281591
# 18940 94.69999999999999% 32m 0s content_loss:0.251408 style_loss:0.030184 total_loss:0.281592
# 18950 94.75% 32m 1s content_loss:0.251410 style_loss:0.030182 total_loss:0.281592
# 18960 94.8% 32m 2s content_loss:0.251402 style_loss:0.030189 total_loss:0.281591
# 18970 94.85% 32m 3s content_loss:0.251402 style_loss:0.030189 total_loss:0.281591
# 18980 94.89999999999999% 32m 4s content_loss:0.251408 style_loss:0.030183 total_loss:0.281592
# 18990 94.95% 32m 5s content_loss:0.251416 style_loss:0.030177 total_loss:0.281593
# 19000 95.0% 32m 6s content_loss:0.251398 style_loss:0.030193 total_loss:0.281591
# 19010 95.05% 32m 7s content_loss:0.251389 style_loss:0.030201 total_loss:0.281591
# 19020 95.1% 32m 8s content_loss:0.251380 style_loss:0.030211 total_loss:0.281591
# 19030 95.15% 32m 9s content_loss:0.251365 style_loss:0.030228 total_loss:0.281592
# 19040 95.19999999999999% 32m 10s content_loss:0.251364 style_loss:0.030229 total_loss:0.281593
# 19050 95.25% 32m 11s content_loss:0.251401 style_loss:0.030190 total_loss:0.281591
# 19060 95.3% 32m 12s content_loss:0.251407 style_loss:0.030184 total_loss:0.281592
# 19070 95.35% 32m 13s content_loss:0.251395 style_loss:0.030196 total_loss:0.281591
# 19080 95.39999999999999% 32m 14s content_loss:0.251392 style_loss:0.030199 total_loss:0.281591
# 19090 95.45% 32m 15s content_loss:0.251400 style_loss:0.030191 total_loss:0.281591
# 19100 95.5% 32m 17s content_loss:0.251420 style_loss:0.030173 total_loss:0.281593
# 19110 95.55% 32m 18s content_loss:0.251418 style_loss:0.030174 total_loss:0.281593
# 19120 95.6% 32m 19s content_loss:0.251370 style_loss:0.030222 total_loss:0.281592
# 19130 95.65% 32m 20s content_loss:0.251392 style_loss:0.030198 total_loss:0.281591
# 19140 95.7% 32m 21s content_loss:0.251401 style_loss:0.030190 total_loss:0.281591
# 19150 95.75% 32m 22s content_loss:0.251396 style_loss:0.030194 total_loss:0.281591
# 19160 95.8% 32m 23s content_loss:0.251398 style_loss:0.030193 total_loss:0.281591
# 19170 95.85000000000001% 32m 24s content_loss:0.251403 style_loss:0.030188 total_loss:0.281591
# 19180 95.89999999999999% 32m 25s content_loss:0.251421 style_loss:0.030172 total_loss:0.281594
# 19190 95.95% 32m 26s content_loss:0.251400 style_loss:0.030191 total_loss:0.281591
# 19200 96.0% 32m 27s content_loss:0.251378 style_loss:0.030213 total_loss:0.281591
# 19210 96.05% 32m 28s content_loss:0.251379 style_loss:0.030213 total_loss:0.281591
# 19220 96.1% 32m 29s content_loss:0.251383 style_loss:0.030208 total_loss:0.281591
# 19230 96.15% 32m 30s content_loss:0.251378 style_loss:0.030213 total_loss:0.281591
# 19240 96.2% 32m 31s content_loss:0.251367 style_loss:0.030226 total_loss:0.281593
# 19250 96.25% 32m 32s content_loss:0.251371 style_loss:0.030221 total_loss:0.281592
# 19260 96.3% 32m 33s content_loss:0.251385 style_loss:0.030205 total_loss:0.281591
# 19270 96.35000000000001% 32m 34s content_loss:0.251393 style_loss:0.030198 total_loss:0.281591
# 19280 96.39999999999999% 32m 35s content_loss:0.251391 style_loss:0.030199 total_loss:0.281591
# 19290 96.45% 32m 36s content_loss:0.251384 style_loss:0.030207 total_loss:0.281591
# 19300 96.5% 32m 37s content_loss:0.251338 style_loss:0.030259 total_loss:0.281598
# 19310 96.55% 32m 38s content_loss:0.251409 style_loss:0.030183 total_loss:0.281592
# 19320 96.6% 32m 39s content_loss:0.251381 style_loss:0.030210 total_loss:0.281591
# 19330 96.65% 32m 40s content_loss:0.251399 style_loss:0.030192 total_loss:0.281591
# 19340 96.7% 32m 41s content_loss:0.251390 style_loss:0.030200 total_loss:0.281591
# 19350 96.75% 32m 42s content_loss:0.251388 style_loss:0.030203 total_loss:0.281591
# 19360 96.8% 32m 43s content_loss:0.251393 style_loss:0.030197 total_loss:0.281591
# 19370 96.85000000000001% 32m 44s content_loss:0.251389 style_loss:0.030202 total_loss:0.281591
# 19380 96.89999999999999% 32m 45s content_loss:0.251390 style_loss:0.030201 total_loss:0.281591
# 19390 96.95% 32m 46s content_loss:0.251389 style_loss:0.030202 total_loss:0.281591
# 19400 97.0% 32m 47s content_loss:0.251388 style_loss:0.030202 total_loss:0.281591
# 19410 97.05% 32m 48s content_loss:0.251379 style_loss:0.030212 total_loss:0.281591
# 19420 97.1% 32m 49s content_loss:0.251347 style_loss:0.030249 total_loss:0.281596
# 19430 97.15% 32m 50s content_loss:0.251398 style_loss:0.030193 total_loss:0.281591
# 19440 97.2% 32m 51s content_loss:0.251404 style_loss:0.030187 total_loss:0.281591
# 19450 97.25% 32m 52s content_loss:0.251382 style_loss:0.030209 total_loss:0.281591
# 19460 97.3% 32m 53s content_loss:0.251385 style_loss:0.030206 total_loss:0.281591
# 19470 97.35000000000001% 32m 54s content_loss:0.251388 style_loss:0.030203 total_loss:0.281591
# 19480 97.39999999999999% 32m 55s content_loss:0.251389 style_loss:0.030202 total_loss:0.281591
# 19490 97.45% 32m 56s content_loss:0.251376 style_loss:0.030215 total_loss:0.281591
# 19500 97.5% 32m 57s content_loss:0.251353 style_loss:0.030243 total_loss:0.281595
# 19510 97.55% 32m 58s content_loss:0.251396 style_loss:0.030195 total_loss:0.281591
# 19520 97.6% 32m 59s content_loss:0.251409 style_loss:0.030183 total_loss:0.281592
# 19530 97.65% 33m 0s content_loss:0.251391 style_loss:0.030200 total_loss:0.281591
# 19540 97.7% 33m 1s content_loss:0.251382 style_loss:0.030209 total_loss:0.281591
# 19550 97.75% 33m 2s content_loss:0.251375 style_loss:0.030216 total_loss:0.281591
# 19560 97.8% 33m 3s content_loss:0.251370 style_loss:0.030222 total_loss:0.281592
# 19570 97.85000000000001% 33m 4s content_loss:0.251376 style_loss:0.030216 total_loss:0.281592
# 19580 97.89999999999999% 33m 5s content_loss:0.251386 style_loss:0.030205 total_loss:0.281591
# 19590 97.95% 33m 6s content_loss:0.251383 style_loss:0.030208 total_loss:0.281591
# 19600 98.0% 33m 7s content_loss:0.251366 style_loss:0.030226 total_loss:0.281592
# 19610 98.05% 33m 8s content_loss:0.251363 style_loss:0.030230 total_loss:0.281593
# 19620 98.1% 33m 9s content_loss:0.251396 style_loss:0.030195 total_loss:0.281591
# 19630 98.15% 33m 10s content_loss:0.251407 style_loss:0.030184 total_loss:0.281591
# 19640 98.2% 33m 11s content_loss:0.251407 style_loss:0.030184 total_loss:0.281591
# 19650 98.25% 33m 12s content_loss:0.251406 style_loss:0.030185 total_loss:0.281591
# 19660 98.3% 33m 13s content_loss:0.251411 style_loss:0.030180 total_loss:0.281592
# 19670 98.35000000000001% 33m 14s content_loss:0.251416 style_loss:0.030176 total_loss:0.281592
# 19680 98.4% 33m 15s content_loss:0.251403 style_loss:0.030188 total_loss:0.281591
# 19690 98.45% 33m 16s content_loss:0.251396 style_loss:0.030195 total_loss:0.281591
# 19700 98.5% 33m 17s content_loss:0.251397 style_loss:0.030194 total_loss:0.281591
# 19710 98.55000000000001% 33m 18s content_loss:0.251419 style_loss:0.030174 total_loss:0.281593
# 19720 98.6% 33m 19s content_loss:0.251413 style_loss:0.030179 total_loss:0.281592
# 19730 98.65% 33m 20s content_loss:0.251380 style_loss:0.030211 total_loss:0.281591
# 19740 98.7% 33m 21s content_loss:0.251381 style_loss:0.030210 total_loss:0.281591
# 19750 98.75% 33m 22s content_loss:0.251384 style_loss:0.030207 total_loss:0.281591
# 19760 98.8% 33m 23s content_loss:0.251382 style_loss:0.030209 total_loss:0.281591
# 19770 98.85000000000001% 33m 24s content_loss:0.251367 style_loss:0.030225 total_loss:0.281592
# 19780 98.9% 33m 25s content_loss:0.251363 style_loss:0.030230 total_loss:0.281593
# 19790 98.95% 33m 26s content_loss:0.251393 style_loss:0.030197 total_loss:0.281591
# 19800 99.0% 33m 27s content_loss:0.251402 style_loss:0.030189 total_loss:0.281591
# 19810 99.05000000000001% 33m 28s content_loss:0.251406 style_loss:0.030186 total_loss:0.281591
# 19820 99.1% 33m 29s content_loss:0.251410 style_loss:0.030181 total_loss:0.281592
# 19830 99.15% 33m 30s content_loss:0.251410 style_loss:0.030182 total_loss:0.281592
# 19840 99.2% 33m 31s content_loss:0.251405 style_loss:0.030186 total_loss:0.281591
# 19850 99.25% 33m 32s content_loss:0.251404 style_loss:0.030187 total_loss:0.281591
# 19860 99.3% 33m 33s content_loss:0.251410 style_loss:0.030182 total_loss:0.281592
# 19870 99.35000000000001% 33m 34s content_loss:0.251413 style_loss:0.030179 total_loss:0.281592
# 19880 99.4% 33m 35s content_loss:0.251401 style_loss:0.030190 total_loss:0.281591
# 19890 99.45% 33m 37s content_loss:0.251394 style_loss:0.030197 total_loss:0.281591
# 19900 99.5% 33m 38s content_loss:0.251395 style_loss:0.030196 total_loss:0.281591
# 19910 99.55000000000001% 33m 39s content_loss:0.251413 style_loss:0.030179 total_loss:0.281592
# 19920 99.6% 33m 40s content_loss:0.251431 style_loss:0.030164 total_loss:0.281595
# 19930 99.65% 33m 41s content_loss:0.251373 style_loss:0.030219 total_loss:0.281592
# 19940 99.7% 33m 42s content_loss:0.251383 style_loss:0.030207 total_loss:0.281591
# 19950 99.75% 33m 43s content_loss:0.251400 style_loss:0.030190 total_loss:0.281591
# 19960 99.8% 33m 44s content_loss:0.251396 style_loss:0.030194 total_loss:0.281591
# 19970 99.85000000000001% 33m 45s content_loss:0.251395 style_loss:0.030195 total_loss:0.281591
# 19980 99.9% 33m 46s content_loss:0.251394 style_loss:0.030197 total_loss:0.281591
# 19990 99.95% 33m 47s content_loss:0.251409 style_loss:0.030183 total_loss:0.281592
# 20000 100.0% 33m 48s content_loss:0.251433 style_loss:0.030162 total_loss:0.281595
